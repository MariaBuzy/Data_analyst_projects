# %% [markdown]
# # Изучение закономерностей, определяющих успешность игр

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Файл-с-данными" data-toc-modified-id="Файл-с-данными-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Файл с данными</a></span><ul class="toc-item"><li><span><a href="#Библиотеки" data-toc-modified-id="Библиотеки-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Библиотеки</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков-и-замена-типов-данных-(при-необходимости)" data-toc-modified-id="Обработка-пропусков-и-замена-типов-данных-(при-необходимости)-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Обработка пропусков и замена типов данных (при необходимости)</a></span></li><li><span><a href="#Столбец-name" data-toc-modified-id="Столбец-name-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Столбец name</a></span></li><li><span><a href="#Столбец-platform" data-toc-modified-id="Столбец-platform-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Столбец platform</a></span></li><li><span><a href="#Столбец-years_of_release" data-toc-modified-id="Столбец-years_of_release-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Столбец years_of_release</a></span></li><li><span><a href="#Столбец-genre" data-toc-modified-id="Столбец-genre-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Столбец genre</a></span></li><li><span><a href="#Столбцы-na_sales,-eu_sales,-jp_sales-и-other_sales" data-toc-modified-id="Столбцы-na_sales,-eu_sales,-jp_sales-и-other_sales-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Столбцы na_sales, eu_sales, jp_sales и other_sales</a></span></li><li><span><a href="#Столбец-critic_score" data-toc-modified-id="Столбец-critic_score-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Столбец critic_score</a></span></li><li><span><a href="#Столбец-user_score" data-toc-modified-id="Столбец-user_score-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Столбец user_score</a></span></li><li><span><a href="#Столбец-rating" data-toc-modified-id="Столбец-rating-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>Столбец rating</a></span></li></ul></li><li><span><a href="#Расчет-суммарных-продаж-во-всех-регионах" data-toc-modified-id="Расчет-суммарных-продаж-во-всех-регионах-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Расчет суммарных продаж во всех регионах</a></span></li><li><span><a href="#Обновление-индексов" data-toc-modified-id="Обновление-индексов-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Обновление индексов</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Оценка-количества-игр,-выпущенных-в-разные-годы" data-toc-modified-id="Оценка-количества-игр,-выпущенных-в-разные-годы-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Оценка количества игр, выпущенных в разные годы</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-изменений-продаж-по-платформам" data-toc-modified-id="Оценка-изменений-продаж-по-платформам-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Оценка изменений продаж по платформам</a></span></li><li><span><a href="#Альтернативная-выборка-за-5-лет-🎈🎈🎈" data-toc-modified-id="Альтернативная-выборка-за-5-лет-🎈🎈🎈-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Альтернативная выборка за 5 лет 🎈🎈🎈</a></span></li><li><span><a href="#Определение-роста-и-падения-продаж" data-toc-modified-id="Определение-роста-и-падения-продаж-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Определение роста и падения продаж</a></span><ul class="toc-item"><li><span><a href="#X360-🎈" data-toc-modified-id="X360-🎈-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>X360 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-АВ-🎈" data-toc-modified-id="Вывод-АВ-🎈-7.4.1.1"><span class="toc-item-num">7.4.1.1&nbsp;&nbsp;</span>Вывод АВ 🎈</a></span></li></ul></li><li><span><a href="#PS3-🎈" data-toc-modified-id="PS3-🎈-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>PS3 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-АВ-🎈" data-toc-modified-id="Вывод-АВ-🎈-7.4.2.1"><span class="toc-item-num">7.4.2.1&nbsp;&nbsp;</span>Вывод АВ 🎈</a></span></li></ul></li><li><span><a href="#Wii" data-toc-modified-id="Wii-7.4.3"><span class="toc-item-num">7.4.3&nbsp;&nbsp;</span>Wii</a></span><ul class="toc-item"><li><span><a href="#Вывод-АВ-🎈" data-toc-modified-id="Вывод-АВ-🎈-7.4.3.1"><span class="toc-item-num">7.4.3.1&nbsp;&nbsp;</span>Вывод АВ 🎈</a></span></li></ul></li><li><span><a href="#PS4-🎈" data-toc-modified-id="PS4-🎈-7.4.4"><span class="toc-item-num">7.4.4&nbsp;&nbsp;</span>PS4 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.4.4.1"><span class="toc-item-num">7.4.4.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#3DS-🎈" data-toc-modified-id="3DS-🎈-7.4.5"><span class="toc-item-num">7.4.5&nbsp;&nbsp;</span>3DS 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.4.5.1"><span class="toc-item-num">7.4.5.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#XOne-🎈" data-toc-modified-id="XOne-🎈-7.4.6"><span class="toc-item-num">7.4.6&nbsp;&nbsp;</span>XOne 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.4.6.1"><span class="toc-item-num">7.4.6.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#WiiU-🎈" data-toc-modified-id="WiiU-🎈-7.4.7"><span class="toc-item-num">7.4.7&nbsp;&nbsp;</span>WiiU 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.4.7.1"><span class="toc-item-num">7.4.7.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#PC-🎈" data-toc-modified-id="PC-🎈-7.4.8"><span class="toc-item-num">7.4.8&nbsp;&nbsp;</span>PC 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-АВ-🎈" data-toc-modified-id="Вывод-АВ-🎈-7.4.8.1"><span class="toc-item-num">7.4.8.1&nbsp;&nbsp;</span>Вывод АВ 🎈</a></span></li></ul></li><li><span><a href="#PSV🎈" data-toc-modified-id="PSV🎈-7.4.9"><span class="toc-item-num">7.4.9&nbsp;&nbsp;</span>PSV🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод-АВ-🎈" data-toc-modified-id="Вывод-АВ-🎈-7.4.9.1"><span class="toc-item-num">7.4.9.1&nbsp;&nbsp;</span>Вывод АВ 🎈</a></span></li></ul></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Опредение-платформ,-лидирующих-по-продажам" data-toc-modified-id="Опредение-платформ,-лидирующих-по-продажам-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Опредение платформ, лидирующих по продажам</a></span><ul class="toc-item"><li><span><a href="#Платформы,-для-которых-выпускались-игры-в-2016-году" data-toc-modified-id="Платформы,-для-которых-выпускались-игры-в-2016-году-7.6.1"><span class="toc-item-num">7.6.1&nbsp;&nbsp;</span>Платформы, для которых выпускались игры в 2016 году</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.6.1.1"><span class="toc-item-num">7.6.1.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#Рейтинг-продаж-по-всем-платформам-за-все-годы" data-toc-modified-id="Рейтинг-продаж-по-всем-платформам-за-все-годы-7.6.2"><span class="toc-item-num">7.6.2&nbsp;&nbsp;</span>Рейтинг продаж по всем платформам за все годы</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.7"><span class="toc-item-num">7.7&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Вывод-🎈" data-toc-modified-id="Вывод-🎈-7.7.1"><span class="toc-item-num">7.7.1&nbsp;&nbsp;</span>Вывод 🎈</a></span></li></ul></li><li><span><a href="#Диаграмма-размаха-по-глобальным-продажам-игр-в-разбивке-по-платформам" data-toc-modified-id="Диаграмма-размаха-по-глобальным-продажам-игр-в-разбивке-по-платформам-7.8"><span class="toc-item-num">7.8&nbsp;&nbsp;</span>Диаграмма размаха по глобальным продажам игр в разбивке по платформам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.8.1"><span class="toc-item-num">7.8.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.9"><span class="toc-item-num">7.9&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Исследование-популярной-платформы" data-toc-modified-id="Исследование-популярной-платформы-7.10"><span class="toc-item-num">7.10&nbsp;&nbsp;</span>Исследование популярной платформы</a></span><ul class="toc-item"><li><span><a href="#Исследую-продажи-и-влияние-факторов-на-них-на-примере-платформы-X360" data-toc-modified-id="Исследую-продажи-и-влияние-факторов-на-них-на-примере-платформы-X360-7.10.1"><span class="toc-item-num">7.10.1&nbsp;&nbsp;</span>Исследую продажи и влияние факторов на них на примере платформы X360</a></span><ul class="toc-item"><li><span><a href="#Влияние-отзывов-критиков-на-продажи" data-toc-modified-id="Влияние-отзывов-критиков-на-продажи-7.10.1.1"><span class="toc-item-num">7.10.1.1&nbsp;&nbsp;</span>Влияние отзывов критиков на продажи</a></span></li><li><span><a href="#АВ" data-toc-modified-id="АВ-7.10.1.2"><span class="toc-item-num">7.10.1.2&nbsp;&nbsp;</span>АВ</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.10.1.3"><span class="toc-item-num">7.10.1.3&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Влияние-отзывов-пользователей-на-продажи" data-toc-modified-id="Влияние-отзывов-пользователей-на-продажи-7.10.1.4"><span class="toc-item-num">7.10.1.4&nbsp;&nbsp;</span>Влияние отзывов пользователей на продажи</a></span></li><li><span><a href="#АВ" data-toc-modified-id="АВ-7.10.1.5"><span class="toc-item-num">7.10.1.5&nbsp;&nbsp;</span>АВ</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.10.1.6"><span class="toc-item-num">7.10.1.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Сравнение-результатов-и-выводов-по-платформам" data-toc-modified-id="Сравнение-результатов-и-выводов-по-платформам-7.11"><span class="toc-item-num">7.11&nbsp;&nbsp;</span>Сравнение результатов и выводов по платформам</a></span><ul class="toc-item"><li><span><a href="#Влияние-отзывов-критиков-на-продажи" data-toc-modified-id="Влияние-отзывов-критиков-на-продажи-7.11.1"><span class="toc-item-num">7.11.1&nbsp;&nbsp;</span>Влияние отзывов критиков на продажи</a></span><ul class="toc-item"><li><span><a href="#PS3" data-toc-modified-id="PS3-7.11.1.1"><span class="toc-item-num">7.11.1.1&nbsp;&nbsp;</span>PS3</a></span></li><li><span><a href="#Wii" data-toc-modified-id="Wii-7.11.1.2"><span class="toc-item-num">7.11.1.2&nbsp;&nbsp;</span>Wii</a></span></li><li><span><a href="#PS4" data-toc-modified-id="PS4-7.11.1.3"><span class="toc-item-num">7.11.1.3&nbsp;&nbsp;</span>PS4</a></span></li><li><span><a href="#XOne-🎈" data-toc-modified-id="XOne-🎈-7.11.1.4"><span class="toc-item-num">7.11.1.4&nbsp;&nbsp;</span>XOne 🎈</a></span></li><li><span><a href="#3DS-🎈" data-toc-modified-id="3DS-🎈-7.11.1.5"><span class="toc-item-num">7.11.1.5&nbsp;&nbsp;</span>3DS 🎈</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.11.2"><span class="toc-item-num">7.11.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Влияние-отзывов-пользователей-на-продажи" data-toc-modified-id="Влияние-отзывов-пользователей-на-продажи-7.11.3"><span class="toc-item-num">7.11.3&nbsp;&nbsp;</span>Влияние отзывов пользователей на продажи</a></span><ul class="toc-item"><li><span><a href="#PS3" data-toc-modified-id="PS3-7.11.3.1"><span class="toc-item-num">7.11.3.1&nbsp;&nbsp;</span>PS3</a></span></li><li><span><a href="#Wii" data-toc-modified-id="Wii-7.11.3.2"><span class="toc-item-num">7.11.3.2&nbsp;&nbsp;</span>Wii</a></span></li><li><span><a href="#PS4" data-toc-modified-id="PS4-7.11.3.3"><span class="toc-item-num">7.11.3.3&nbsp;&nbsp;</span>PS4</a></span></li><li><span><a href="#PC" data-toc-modified-id="PC-7.11.3.4"><span class="toc-item-num">7.11.3.4&nbsp;&nbsp;</span>PC</a></span></li><li><span><a href="#3DS" data-toc-modified-id="3DS-7.11.3.5"><span class="toc-item-num">7.11.3.5&nbsp;&nbsp;</span>3DS</a></span></li><li><span><a href="#XOne" data-toc-modified-id="XOne-7.11.3.6"><span class="toc-item-num">7.11.3.6&nbsp;&nbsp;</span>XOne</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.11.4"><span class="toc-item-num">7.11.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-самых-прибыльных-жанров" data-toc-modified-id="Оценка-самых-прибыльных-жанров-7.12"><span class="toc-item-num">7.12&nbsp;&nbsp;</span>Оценка самых прибыльных жанров</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.12.1"><span class="toc-item-num">7.12.1&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Количство-продаж-по-жанрам" data-toc-modified-id="Количство-продаж-по-жанрам-7.12.2"><span class="toc-item-num">7.12.2&nbsp;&nbsp;</span>Количство продаж по жанрам</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.12.2.1"><span class="toc-item-num">7.12.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.12.3"><span class="toc-item-num">7.12.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценка-количества-продаж-к-количеству-изданных-игр-🎈" data-toc-modified-id="Оценка-количества-продаж-к-количеству-изданных-игр-🎈-7.13"><span class="toc-item-num">7.13&nbsp;&nbsp;</span>Оценка количества продаж к количеству изданных игр 🎈</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.13.1"><span class="toc-item-num">7.13.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Портрет-пользователя-по-регионам" data-toc-modified-id="Портрет-пользователя-по-регионам-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Портрет пользователя по регионам</a></span><ul class="toc-item"><li><span><a href="#Портрет-пользователя-NA-региона" data-toc-modified-id="Портрет-пользователя-NA-региона-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Портрет пользователя NA-региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-платформ" data-toc-modified-id="Топ-5-платформ-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Топ-5 платформ</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Топ-5-жанров" data-toc-modified-id="Топ-5-жанров-8.1.3"><span class="toc-item-num">8.1.3&nbsp;&nbsp;</span>Топ-5 жанров</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.1.3.1"><span class="toc-item-num">8.1.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-регионе-8.1.4"><span class="toc-item-num">8.1.4&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в регионе</a></span></li><li><span><a href="#Возможные-причины-отсутствия-рейтинга-🎈" data-toc-modified-id="Возможные-причины-отсутствия-рейтинга-🎈-8.1.5"><span class="toc-item-num">8.1.5&nbsp;&nbsp;</span>Возможные причины отсутствия рейтинга 🎈</a></span></li><li><span><a href="#Портрет-пользователя-из-NA-региона.-Вывод-🎈" data-toc-modified-id="Портрет-пользователя-из-NA-региона.-Вывод-🎈-8.1.6"><span class="toc-item-num">8.1.6&nbsp;&nbsp;</span>Портрет пользователя из NA-региона. Вывод 🎈</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-EU-региона" data-toc-modified-id="Портрет-пользователя-EU-региона-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Портрет пользователя EU-региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-платформ" data-toc-modified-id="Топ-5-платформ-8.2.1"><span class="toc-item-num">8.2.1&nbsp;&nbsp;</span>Топ-5 платформ</a></span></li><li><span><a href="#Топ-5-жанров" data-toc-modified-id="Топ-5-жанров-8.2.2"><span class="toc-item-num">8.2.2&nbsp;&nbsp;</span>Топ-5 жанров</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-регионе-8.2.3"><span class="toc-item-num">8.2.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в регионе</a></span></li><li><span><a href="#Портрет-пользователя-из-Европы.-Вывод" data-toc-modified-id="Портрет-пользователя-из-Европы.-Вывод-8.2.4"><span class="toc-item-num">8.2.4&nbsp;&nbsp;</span>Портрет пользователя из Европы. Вывод</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-JP-региона" data-toc-modified-id="Портрет-пользователя-JP-региона-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Портрет пользователя JP-региона</a></span><ul class="toc-item"><li><span><a href="#Топ-5-платформ" data-toc-modified-id="Топ-5-платформ-8.3.1"><span class="toc-item-num">8.3.1&nbsp;&nbsp;</span>Топ-5 платформ</a></span></li><li><span><a href="#Топ-5-жанров" data-toc-modified-id="Топ-5-жанров-8.3.2"><span class="toc-item-num">8.3.2&nbsp;&nbsp;</span>Топ-5 жанров</a></span></li><li><span><a href="#Влияние-рейтинга-ESRB-на-продажи-в-регионе" data-toc-modified-id="Влияние-рейтинга-ESRB-на-продажи-в-регионе-8.3.3"><span class="toc-item-num">8.3.3&nbsp;&nbsp;</span>Влияние рейтинга ESRB на продажи в регионе</a></span></li><li><span><a href="#Портрет-пользователя-из-Ja-региона.-Вывод" data-toc-modified-id="Портрет-пользователя-из-Ja-региона.-Вывод-8.3.4"><span class="toc-item-num">8.3.4&nbsp;&nbsp;</span>Портрет пользователя из Ja-региона. Вывод</a></span></li></ul></li><li><span><a href="#Вывод-о-портрете-пользователя-из-разных-регионов" data-toc-modified-id="Вывод-о-портрете-пользователя-из-разных-регионов-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Вывод о портрете пользователя из разных регионов</a></span></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Проверка-гипотезы-&quot;Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые&quot;" data-toc-modified-id="Проверка-гипотезы-&quot;Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые&quot;-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Проверка гипотезы "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Проверка-гипотезы-&quot;Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные&quot;" data-toc-modified-id="Проверка-гипотезы-&quot;Средние-пользовательские-рейтинги-жанров-Action-и-Sports-разные&quot;-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Проверка гипотезы "Средние пользовательские рейтинги жанров Action и Sports разные"</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Вывод</a></span><ul class="toc-item"><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта
# Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и игровые платформы. Нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании для интернет-магазина компьютерных игр, который продает игры по всему миру.
#
# Данные до 2016 года. дата исследования - декабрь 2016 года, нуджно дать рекомендации для рекламной кампании на 2017 год.

# %% [markdown]
# ## Описание данных
# **Name** — название игры
# **Platform** — платформа
# **Year_of_Release** — год выпуска
# **Genre** — жанр игры
# **NA_sales** — продажи в Северной Америке (миллионы проданных копий)
# **EU_sales** — продажи в Европе (миллионы проданных копий)
# **JP_sales** — продажи в Японии (миллионы проданных копий)
# **Other_sales** — продажи в других странах (миллионы проданных копий)
# **Critic_Score** — оценка критиков (максимум 100)
# **User_Score** — оценка пользователей (максимум 10)
# **Rating** — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ## Файл с данными

# %% [markdown]
# ### Библиотеки

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt

# %% [markdown]
# Подгружаю файл с данными.

# %%
df = pd.read_csv('games.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# ### Вывод
# В таблице 16715 строк. Названия столбцов указаны с прописных букв, нужно будет испрвавить.
# В полях Name, Year_of_Release, Genre, Critic_Score, User_Score, Rating есть пропущенные значения.
# В поле Year_of_Release значение с типом float, так как это год выпуска игры, его можно перевести в тип integer.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Привожу названия столбцов к нижнему регистру.

# %%
df.columns = df.columns.str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Проверяю датасет на наличие дубликатов.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Ищу дубликаты по паре имя-консоль

# %%
df[['name','platform']].duplicated().sum()
# Out:
# 5

# %% [markdown]
# Нашлись 5 дубликатов, удаляю их.

# %%
df = df.drop_duplicates(subset = ['name','platform']).reset_index(drop=True)

# %% [markdown]
# ### Обработка пропусков и замена типов данных (при необходимости)

# %% [markdown]
# ### Столбец name

# %%
df[df['name'].isna()]
# Out:
#     name platform  year_of_release genre  na_sales  eu_sales  jp_sales  \
# 659  NaN      GEN           1993.0   NaN      1.78      0.53       0.0
#
#      other_sales  critic_score user_score rating
# 659         0.08           NaN        NaN    NaN

# %% [markdown]
# В поле name всего два пропущенных значения, игры старые, 1993 года издания, ценной информации мало, в целом строки можно удалить.

# %%
df = df.dropna(subset=['name'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16709 entries, 0 to 16709
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16709 non-null  object
#  2   year_of_release  16441 non-null  float64
#  3   genre            16709 non-null  object
#  4   na_sales         16709 non-null  float64
#  5   eu_sales         16709 non-null  float64
#  6   jp_sales         16709 non-null  float64
#  7   other_sales      16709 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       10010 non-null  object
#  10  rating           9945 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Столбец platform

# %%
df.groupby('platform')['platform'].count()
# Out:
# platform
# 2600     133
# 3DO        3
# 3DS      520
# DC        52
# DS      2151
# GB        98
# GBA      822
# GC       556
# GEN       27
# GG         1
# N64      319
# NES       98
# NG        12
# PC       973
# PCFX       1
# PS      1197
# PS2     2161
# PS3     1329
# PS4      392
# PSP     1209
# PSV      430
# SAT      173
# SCD        6
# SNES     239
# TG16       2
# WS         6
# Wii     1320
# WiiU     147
# X360    1261
# XB       824
# XOne     247
# Name: platform, dtype: int64

# %% [markdown]
# Пропущеных значений нет, аномалий нет, столбец можно оставить без изменений.
# Перехожу к следующему столбцу, в нем есть пропущенные значения.

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release     268
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8576
# user_score         6699
# rating             6764
# dtype: int64

# %% [markdown]
# ### Столбец years_of_release

# %% [markdown]
# В столбце 269 пропущенных значений, удалять я их не хочу, так как они могут содержать ценную информацию.
# Меняю все пропущенные значения на какой-нибудь год, которого нет в данных.
# Значения в столбце цеочисленные, поэтому можно заменить тип данных на integer.

# %%
df['year_of_release'] = df['year_of_release'].fillna(215200).astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16709 entries, 0 to 16709
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16709 non-null  object
#  2   year_of_release  16709 non-null  int32
#  3   genre            16709 non-null  object
#  4   na_sales         16709 non-null  float64
#  5   eu_sales         16709 non-null  float64
#  6   jp_sales         16709 non-null  float64
#  7   other_sales      16709 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       10010 non-null  object
#  10  rating           9945 non-null   object
# dtypes: float64(5), int32(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Столбец genre

# %%
df.groupby('genre')['genre'].count()
# Out:
# genre
# Action          3369
# Adventure       1303
# Fighting         849
# Misc            1750
# Platform         887
# Puzzle           580
# Racing          1247
# Role-Playing    1498
# Shooter         1323
# Simulation       873
# Sports          2347
# Strategy         683
# Name: genre, dtype: int64

# %% [markdown]
# Пропущенных значений нет, аномалий нет.

# %% [markdown]
# ### Столбцы na_sales, eu_sales, jp_sales и other_sales
# В столбцах na_sales, eu_sales, jp_sales и other_sales оставляю все без изменений, так как пропущенных значений нет.

# %% [markdown]
# ### Столбец critic_score

# %%
df['critic_score'].value_counts()
# Out:
# 70.0    256
# 71.0    254
# 75.0    245
# 78.0    240
# 73.0    238
#        ...
# 20.0      3
# 21.0      1
# 17.0      1
# 22.0      1
# 13.0      1
# Name: critic_score, Length: 82, dtype: int64

# %%
df[df['critic_score'].isna()]['name'].count()
# Out:
# 8576

# %% [markdown]
# Оставляю пропущенные значения без изменения, так как это показатель того, что критикам эта игра не попадалась на оценку.

# %% [markdown]
# ### Столбец user_score

# %%
df['user_score'].value_counts()
# Out:
# tbd    2424
# 7.8     324
# 8       290
# 8.2     282
# 8.3     254
#        ...
# 1.1       2
# 1.9       2
# 9.6       2
# 0         1
# 9.7       1
# Name: user_score, Length: 96, dtype: int64

# %% [markdown]
# В строках появилось неопознанное значение tbd.
# Можно предположить, что это аббревиатура to be discussed или to be defined, что на момент выгрузки то же самое, что отсутствие оценки. Можно заменить tbd на NaN.
# Можно предположить, что остальные NaN появились потому что пользовательский рейтинг по данным играм не оценивался в тех источниках, из которых были получены данные.

# %%
df['user_score'] = df['user_score'].replace('tbd', np.NaN).astype('float')
df['user_score'].value_counts()
# Out:
# 7.8    324
# 8.0    290
# 8.2    282
# 8.3    254
# 8.5    251
#       ...
# 1.5      2
# 0.3      2
# 1.1      2
# 0.0      1
# 9.7      1
# Name: user_score, Length: 95, dtype: int64

# %%
df.query('user_score==0') # или все очень плохо или это тоже NaN, так как такая игра только одна, оставляю ее как есть.
# Out:
#                                     name platform  year_of_release      genre  \
# 2834  My Little Pony: Pinkie Pie's Party       DS             2008  Adventure
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 2834      0.66       0.0       0.0         0.06           NaN         0.0
#
#      rating
# 2834      E

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16709 entries, 0 to 16709
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16709 non-null  object
#  1   platform         16709 non-null  object
#  2   year_of_release  16709 non-null  int32
#  3   genre            16709 non-null  object
#  4   na_sales         16709 non-null  float64
#  5   eu_sales         16709 non-null  float64
#  6   jp_sales         16709 non-null  float64
#  7   other_sales      16709 non-null  float64
#  8   critic_score     8133 non-null   float64
#  9   user_score       7586 non-null   float64
#  10  rating           9945 non-null   object
# dtypes: float64(6), int32(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# ### Столбец rating

# %%
df['rating'].value_counts()
# Out:
# E       3989
# T       2959
# M       1563
# E10+    1419
# EC         8
# K-A        3
# RP         3
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# По данным с [википедии](https://ru.wikipedia.org/wiki/Entertainment_Software_Rating_Board):
# * RP - в данный момент игра находится на оценке в ESRB, это то же самое, что NAN
# * K-A  - то то же самое, что и Е.
# Заменяю значения.

# %%
df['rating'] = df['rating'].replace({'RP': np.NaN, 'K-A':'E'})
df['rating'].value_counts()
# Out:
# E       3992
# T       2959
# M       1563
# E10+    1419
# EC         8
# AO         1
# Name: rating, dtype: int64

# %% [markdown]
# ## Расчет суммарных продаж во всех регионах

# %%
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 0     28.96      3.77         8.45          76.0         8.0      E
# 1      3.58      6.81         0.77           NaN         NaN    NaN
# 2     12.76      3.79         3.29          82.0         8.3      E
# 3     10.93      3.28         2.95          80.0         8.0      E
# 4      8.89     10.22         1.00           NaN         NaN    NaN

# %% [markdown]
# Добавляю столбец с суммарными продажами игр по всем регионам.

# %%
df['all_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales'] + df['other_sales']
df.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  all_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %% [markdown]
# ## Обновление индексов
# Обновляю индексы, так как удаляла две строки по полю name и больше никаких удалений строк не предвидится.

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Оценка количества игр, выпущенных в разные годы

# %%
df.groupby('year_of_release')['name'].count().plot(kind = 'bar', figsize = (12,9))
plt.title('Выпуск игр по годам', fontsize = 14)
plt.xlabel('Год выпуска', color = 'green', fontsize = 14)
plt.ylabel('Количество выпущенных игр', color = 'green', fontsize = 14)
plt.xticks(rotation = 45);

# %% [markdown]
# #### Вывод
# Начиная с 1994 года начинается рост выпуска игр. Больше всего игр выпустили в 2008 и 2009 году.
#
# Для планирования рекламного бюджета на 2017 год не стоит рассматривать игры, выпущенные раньше 2002 года. В 2002 году произошло резкое увеличение выпуска игр.
# Смотрю, сколько строк останется в выборке, если ее ограничить 2002 годом и убрать те игры, для которых год выпуска не был указан.

# %%
df.query('2002 <=year_of_release<215200')['name'].count()
# Out:
# 13635

# %%
df_15_years = df.query('2002 <=year_of_release<215200')

# %% [markdown]
# ### Оценка изменений продаж по платформам

# %% [markdown]
# Нахожу Топ-10 платформ с наибольшими продажами.

# %%
top_10_platform = df_15_years.pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum').sort_values(by='all_sales', ascending = False).head(10)
top_10_platform
# Out:
#           all_sales
# platform
# PS2         1027.96
# X360         959.99
# PS3          931.33
# Wii          891.18
# DS           802.76
# PS4          314.14
# PSP          289.53
# 3DS          257.81
# GBA          251.28
# XB           228.32

# %% [markdown]
# Строю график для наглядности.

# %%
top_10_platform.plot(kind = 'bar',figsize = (7,5))
plt.title('Продажи игр для Топ-10 платформ', fontsize = 14)
plt.xlabel('Платформы', color = 'green', fontsize = 14)
plt.ylabel('Количество проданных копий игр', color = 'green', fontsize = 14);

# %% [markdown]
# Оставляю в таблице за последние 15 лет только Топ-10 платформ.

# %%
df_actual = (df_15_years.join(top_10_platform, on ='platform', how = 'right', lsuffix = '_region', rsuffix='_platform')
             .reset_index(drop=True))
df_actual.head()
# Out:
#                             name platform  year_of_release   genre  na_sales  \
# 0  Grand Theft Auto: San Andreas      PS2             2004  Action      9.43
# 1    Grand Theft Auto: Vice City      PS2             2002  Action      8.41
# 2                 Gran Turismo 4      PS2             2004  Racing      3.01
# 3     Need for Speed Underground      PS2             2003  Racing      3.27
# 4   Need for Speed Underground 2      PS2             2004  Racing      2.71
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  \
# 0      0.40      0.41        10.57          95.0         9.0      M
# 1      5.49      0.47         1.78          95.0         8.7      M
# 2      0.01      1.10         7.53          89.0         8.5      E
# 3      2.83      0.08         1.02          85.0         8.6      E
# 4      3.02      0.08         1.09          82.0         8.6      E
#
#    all_sales_region  all_sales_platform
# 0             20.81             1027.96
# ...

# %% [markdown]
# Строю сводную таблицу по платформам и годам.

# %%
years_platforms = df_actual.pivot_table(index = ['platform','year_of_release'], values = 'name', aggfunc = 'count')
years_platforms.head(10)
# Out:
#                           name
# platform year_of_release
# 3DS      2011              116
#          2012               93
#          2013               91
#          2014               80
#          2015               86
#          2016               46
# DS       2004               23
#          2005              118
#          2006              201
#          2007              376

# %% [markdown]
# Смотрю, сколько лет для платформы выпускаеются игры.

# %%
years_platforms.reset_index().plot(x = 'year_of_release', y = 'platform', kind="scatter")
plt.title('Выпуск игр для Топ-10 платформ', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Платформы', color = 'green', fontsize = 14);

# %% [markdown]
# Для многих приставок игры выпускаются более 10 лет.
# Выборку в 15 лет можно считать репрезентативной, но некотрые платформы прекратили свое существование и прогноз по продажам игр для них на 2017 год будет неактуальным. Таким образом, оставляю выборку по годам, начиная с 2006 года, но возвращаю все платформы.

# %%
life_cycle = (df.query('year_of_release !=215200')
.pivot_table(index = ['platform'], values = 'year_of_release', aggfunc = ['min','max']))
life_cycle.columns = ['start_of_sales','end_of_sales']
life_cycle['life_cycle'] = life_cycle['end_of_sales'] - life_cycle['start_of_sales']
life_cycle
# Out:
#           start_of_sales  end_of_sales  life_cycle
# platform
# 2600                1980          1989           9
# 3DO                 1994          1995           1
# 3DS                 2011          2016           5
# DC                  1998          2008          10
# DS                  1985          2013          28
# GB                  1988          2001          13
# GBA                 2000          2007           7
# GC                  2001          2007           6
# GEN                 1990          1994           4
# GG                  1992          1992           0
# N64                 1996          2002           6
# NES                 1983          1994          11
# NG                  1993          1996           3
# PC                  1985          2016          31
# PCFX                1996          1996           0
# PS                  1994          2003           9
# PS2                 2000          2011          11
# ...

# %%
print('Средний срок жизни платформы:', life_cycle['life_cycle'].median()) #беру медиану, т.к. некоторые платформы очень живучие
# Out:
# Средний срок жизни платформы: 6.0

# %%
platforms_15_year = df_15_years.pivot_table(index = ['platform','year_of_release'], values = 'name', aggfunc = 'count')
platforms_15_year.reset_index().plot(x = 'year_of_release', y = 'platform', kind="scatter")
# Out:
# <AxesSubplot:xlabel='year_of_release', ylabel='platform'>

# %% [markdown]
# Нахожу список живых платформ на 2016 год. Среди них нужно искать рост и падение продаж, так как платформы, которые уже не выпускаются, точно не должны иметь рост продаж в 2017 году.

# %%
list_platform = df.query('year_of_release == 2016')['platform'].unique()
list_platform
# Out:
# array(['PS4', '3DS', 'XOne', 'WiiU', 'PS3', 'PC', 'X360', 'PSV', 'Wii'],
#       dtype=object)

# %% [markdown]
# Обновляю выборку, по которой буду проводить исследование, ограничивая ее 2006 годом.

# %%
(df.query('genre == "Strategy"') #обоснование к комментарию выше
 .pivot_table(index = 'platform', values = 'genre', aggfunc = 'count')
 .sort_values(by='genre', ascending=False).head())
# Out:
#           genre
# platform
# PC          188
# DS           79
# PS           71
# PS2          71
# PSP          60

# %%
(df.query('genre == "Sports"') #обоснование к комментарию выше
 .pivot_table(index = 'platform', values = 'genre', aggfunc = 'count')
 .sort_values(by='genre', ascending=False).head())
# Out:
#           genre
# platform
# PS2         400
# Wii         260
# PS          222
# X360        217
# PS3         213

# %%
(df.query('platform == "Wii"') #обоснование к комментарию выше
 .pivot_table(index = 'genre', values = 'platform', aggfunc = 'count')
 .sort_values(by='platform', ascending=False).head())
# Out:
#             platform
# genre
# Misc             280
# Sports           260
# Action           237
# Racing            93
# Simulation        87

# %%
df_actual = df.query('platform in @list_platform and year_of_release>=2006').reset_index(drop=True)
df_actual
# Out:
#                                name platform  year_of_release       genre  \
# 0                        Wii Sports      Wii             2006      Sports
# 1                    Mario Kart Wii      Wii             2008      Racing
# 2                 Wii Sports Resort      Wii             2009      Sports
# 3                          Wii Play      Wii             2006        Misc
# 4         New Super Mario Bros. Wii      Wii             2009    Platform
# ...                             ...      ...              ...         ...
# 6416               Aiyoku no Eustia      PSV             2014        Misc
# 6417  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 6418               LMA Manager 2007     X360             2006      Sports
# 6419        Haitaka no Psychedelica      PSV             2016   Adventure
# 6420            Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# ...

# %% [markdown]
# ### Альтернативная выборка за 5 лет 🎈🎈🎈

# %%
df_alternative = df.query('platform in @list_platform and year_of_release>=2011').reset_index(drop=True) #альтернативная выборка
df_alternative # осталось в 2 раза меньше строк, далее буду помечать ее как АВ
# Out:
#                                 name platform  year_of_release         genre  \
# 0                 Grand Theft Auto V      PS3             2013        Action
# 1                 Grand Theft Auto V     X360             2013        Action
# 2     Call of Duty: Modern Warfare 3     X360             2011       Shooter
# 3          Call of Duty: Black Ops 3      PS4             2015       Shooter
# 4                Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# ...                              ...      ...              ...           ...
# 3626                Strawberry Nauts      PSV             2016     Adventure
# 3627                Aiyoku no Eustia      PSV             2014          Misc
# 3628   Samurai Warriors: Sanada Maru      PS3             2016        Action
# 3629         Haitaka no Psychedelica      PSV             2016     Adventure
# 3630             Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# ### Определение роста и падения продаж

# %%
(df_actual
 .pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum')
 .sort_values(by='all_sales', ascending = False).head(10)) # нахожу топ-10 по продажам
# Out:
#           all_sales
# platform
# X360         963.17
# PS3          939.16
# Wii          907.51
# PS4          314.14
# 3DS          259.00
# PC           167.10
# XOne         159.32
# WiiU          82.19
# PSV           54.07

# %%
(df_alternative
 .pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum')
 .sort_values(by='all_sales', ascending = False).head(10)) # нахожу топ-10 по продажам
# Out:
#           all_sales
# platform
# PS3          453.39
# X360         390.56
# PS4          314.14
# 3DS          259.00
# XOne         159.32
# Wii          111.35
# PC           101.36
# WiiU          82.19
# PSV           54.07

# %% [markdown]
# #### X360 🎈

# %%
(df_actual.query('platform == "X360" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для X360', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "X360" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для X360', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод АВ 🎈
# На альтернативной выборке наблюдается плавное падение продаж для X360 от пика продаж в 2011 году.

# %% [markdown]
# #### PS3 🎈

# %%
(df_actual.query('platform == "PS3" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PS3', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "PS3" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PS3 (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод АВ 🎈
# На альтернативной выборке наблюдается плавное падение продаж для PS3 от пика продаж в 2010 году.

# %% [markdown]
# #### Wii

# %%
(df_actual.query('platform == "Wii" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для Wii', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "Wii" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для Wii (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод АВ 🎈
# На альтернативной выборке наблюдается плавное падение продаж для Wii от пика продаж в 2010 году.

# %% [markdown]
# #### PS4 🎈

# %%
(df_actual.query('platform == "PS4" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PS4', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "PS4" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PS4 (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод 🎈
# График без изменений.

# %% [markdown]
# #### 3DS 🎈

# %%
(df_actual.query('platform == "3DS" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для 3DS', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "3DS" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для 3DS (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод 🎈
# График без изменений.

# %% [markdown]
# #### XOne 🎈

# %%
(df_actual.query('platform == "XOne" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для XOne', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "XOne" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для XOne (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод 🎈
# График без изменений.

# %% [markdown]
# #### WiiU 🎈

# %%
(df_actual.query('platform == "WiiU" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для WiiU', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "WiiU" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для WiiU (АВ)', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод 🎈
# График без изменений.

# %% [markdown]
# #### PC 🎈

# %%
(df_actual.query('platform == "PC" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PC', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "PC" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PC', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод АВ 🎈
# На альтернативной выборке наблюдается плавное падение продаж для PC от пика продаж в 2011 году.

# %% [markdown]
# #### PSV🎈

# %%
(df_actual.query('platform == "PSV" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PSV', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
(df_alternative.query('platform == "PSV" and year_of_release !=215200')
 .pivot_table(index = ['platform', 'year_of_release'], values= 'all_sales',aggfunc = 'sum' )
 .plot())
plt.title('Продажи игр для PSV', fontsize = 14)
plt.xlabel('Годы', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### Вывод АВ 🎈
# График остался практически без изменений, общая тенденция после 2011 года сохраняется.

# %% [markdown]
# ### Вывод
# **Рост продаж** наблюдается у PS4 и XOne
# **Падение продаж** у 3DS, WiiU, PS3, X360, PSV, Wii
#
# 🎈 В целом вывод не поменялся

# %%
# КОД РЕВЬЮЕРА

df_actual.pivot_table(index='year_of_release', columns='platform', values='all_sales', aggfunc='sum').loc[[2015, 2016]]
# Out:
# platform           3DS    PC    PS3     PS4   PSV   Wii   WiiU   X360   XOne
# year_of_release
# 2015             27.78  8.52  16.82  118.90  6.25  1.14  16.35  11.96  60.14
# 2016             15.14  5.25   3.60   69.25  4.25  0.18   4.60   1.52  26.15

# %% [markdown]
# ### Опредение платформ, лидирующих по продажам

# %% [markdown]
# #### Платформы, для которых выпускались игры в 2016 году

# %%
platforms_2016 = (df_actual.pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum')
                  .sort_values(by = 'all_sales', ascending = False))
platforms_2016
# Out:
#           all_sales
# platform
# X360         963.17
# PS3          939.16
# Wii          907.51
# PS4          314.14
# 3DS          259.00
# PC           167.10
# XOne         159.32
# WiiU          82.19
# PSV           54.07

# %%
platforms_2016_ab = (df_alternative.pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum')
                     .sort_values(by = 'all_sales', ascending = False))
platforms_2016_ab
# Out:
#           all_sales
# platform
# PS3          453.39
# X360         390.56
# PS4          314.14
# 3DS          259.00
# XOne         159.32
# Wii          111.35
# PC           101.36
# WiiU          82.19
# PSV           54.07

# %% [markdown]
# ##### Вывод 🎈
# Набор популярных платформ не изменился, но изменился порядок, PS3 стала самой популярной платформой, X360 заняла второе место. Wii уползла с 3 на 6 PC с 5 на 7.

# %% [markdown]
# #### Рейтинг продаж по всем платформам за все годы

# %%
(df.pivot_table(index = 'platform', values = 'all_sales', aggfunc = 'sum')
.sort_values(by = 'all_sales', ascending = False).head(10))
# Out:
#           all_sales
# platform
# PS2         1255.77
# X360         970.17
# PS3          939.16
# Wii          907.51
# DS           806.12
# PS           730.86
# GBA          317.85
# PS4          314.14
# PSP          294.05
# PC           259.44

# %% [markdown]
# ### Вывод
# Из работающих на 2016 год платформ, наибольшие продажи у X360, PS3 и **Wii**.
# За весь период наблюдений самые большие продажи были у PS2, X360 и PS3.
#
# Беру TOP-5 платформ, для которых провожу дальнейшее исследование.
#
# 🎈
# Из работающих на 2016 год платформ, наибольшие продажи у X360, PS3 и **PS4**.  Остальные наблюдения без изменений.

# %%
top_5 = platforms_2016.head()
top_5
# Out:
#           all_sales
# platform
# X360         963.17
# PS3          939.16
# Wii          907.51
# PS4          314.14
# 3DS          259.00

# %%
top_5_ab = platforms_2016_ab.head()
top_5_ab
# Out:
#           all_sales
# platform
# PS3          453.39
# X360         390.56
# PS4          314.14
# 3DS          259.00
# XOne         159.32

# %%
display(platforms_2016.head(7))
display(platforms_2016_ab.head(7)) # на топ-7 список платформ совпадает. Wii упала по продажам. 
# Что интересно, X360, PS3 и Wii в первой таблице по 10 лет, PS4 - свежая 2013 года. 
# Получается что продажи PS4  за 3 года сопоставимы с продажами X360 и PS3, которые раньше вышли на рынок.
# Я немножко погуглила, если у пользователя была PS3, то он может за доплату перенести некоторые свои игры на PS4.
# Out:
#           all_sales
# platform
# X360         963.17
# PS3          939.16
# Wii          907.51
# PS4          314.14
# 3DS          259.00
# PC           167.10
# XOne         159.32
#           all_sales
# platform
# PS3          453.39
# X360         390.56
# PS4          314.14
# 3DS          259.00
# XOne         159.32
# Wii          111.35
# PC           101.36

# %% [markdown]
# #### Вывод 🎈
# На пятилетнем отрезке только одна платформа не попала в топ-5 - Wii, ее место заняла Xone.

# %% [markdown]
# ### Диаграмма размаха по глобальным продажам игр в разбивке по платформам

# %%
top_5.boxplot();

# %% [markdown]
# #### Вывод
# 25% продаж по TOP-5 платформам составили менее 300 миллионов копий.
# Медиана близка к верхнему квартилю. Это означает, что 50% платформ продали около 900 миллионов копий. А еще 25% продали еще на 50 миллионов копий больше.
# Аномальных значений на диаграмме нет, ни одна платформа не продавала каое-то рекордное количество копий своих игр.

# %%
top_5 = top_5.reset_index() 
top_5_list = list(top_5['platform']) # создаю список платформ для фильтрации датафрейма

# %%
forbp = df_actual.query('platform in @top_5_list')

boxplot = forbp.boxplot(column =['all_sales'], by = ['platform'], figsize = (15,7))
plt.ylim(0, 40);

# %%
top_5_ab = top_5_ab.reset_index() 
top_5_ab_list = list(top_5_ab['platform']) # создаю список платформ для фильтрации датафрейма

# %%
forbp = df_alternative.query('platform in @top_5_list')

boxplot = forbp.boxplot(column =['all_sales'], by = ['platform'], figsize = (15,7))
plt.ylim(0, 23);

# %% [markdown]
# ### Вывод
# Для всех топ-5 платформ характерны большие выбросы и очень маленький "ящик".
# Это значит, что какие-то игры пользовались "бешенной" популярностью по сравнению с основной массой игр и их продажи зашкаливали. Самые далекие всплески "бешенной" популярность была на Wii.
#
# 🎈 В альтернативной выборке так же большие выбросы при маленьком "ящике". Самая популярная игра на PS3 далеко оторвалась ото всех.
#
# Ниже посмотрю, что же это за игры такие.

# %%
df_actual.query('platform == "Wii"').sort_values(by='all_sales', ascending=False).head(5)
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 0                 Wii Sports      Wii             2006    Sports     41.36
# 1             Mario Kart Wii      Wii             2008    Racing     15.68
# 2          Wii Sports Resort      Wii             2009    Sports     15.61
# 3                   Wii Play      Wii             2006      Misc     13.96
# 4  New Super Mario Bros. Wii      Wii             2009  Platform     14.44
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  all_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1     12.76      3.79         3.29          82.0         8.3      E      35.52
# 2     10.93      3.28         2.95          80.0         8.0      E      32.77
# 3      9.18      2.93         2.84          58.0         6.6      E      28.91
# 4      6.94      4.70         2.24          87.0         8.4      E      28.32

# %%
df_alternative.query('platform == "PS3"').sort_values(by='all_sales', ascending=False).head(5)
# Out:
#                               name platform  year_of_release    genre  \
# 0               Grand Theft Auto V      PS3             2013   Action
# 5       Call of Duty: Black Ops II      PS3             2012  Shooter
# 7   Call of Duty: Modern Warfare 3      PS3             2011  Shooter
# 16            Call of Duty: Ghosts      PS3             2013  Shooter
# 21                  FIFA Soccer 13      PS3             2012   Action
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0       7.02      9.09      0.98         3.96          97.0         8.2
# 5       4.99      5.73      0.65         2.42          83.0         5.3
# 7       5.54      5.73      0.49         1.57          88.0         3.2
# 16      4.10      3.63      0.38         1.25          71.0         2.6
# 21      1.06      5.01      0.13         1.97          88.0         6.6
#
#    rating  all_sales
# 0       M      21.05
# 5       M      13.79
# 7       M      13.33
# ...

# %% [markdown]
# ### Исследование популярной платформы
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# #### Исследую продажи и влияние факторов на них на примере платформы X360

# %%
x360 = df_actual.query('platform =="X360"')
x360.head()
# Out:
#                               name platform  year_of_release    genre  \
# 6               Kinect Adventures!     X360             2010     Misc
# 9               Grand Theft Auto V     X360             2013   Action
# 10  Call of Duty: Modern Warfare 3     X360             2011  Shooter
# 12         Call of Duty: Black Ops     X360             2010  Shooter
# 15      Call of Duty: Black Ops II     X360             2012  Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 6      15.00      4.89      0.24         1.69          61.0         6.3
# 9       9.66      5.14      0.06         1.41          97.0         8.1
# 10      9.04      4.24      0.13         1.32          88.0         3.4
# 12      9.70      3.68      0.11         1.13          87.0         6.3
# 15      8.25      4.24      0.07         1.12          83.0         4.8
#
#    rating  all_sales
# 6       E      21.82
# 9       M      16.27
# 10      M      14.73
# ...

# %% [markdown]
# ##### Влияние отзывов критиков на продажи

# %%
x360.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
x360['critic_score'].corr(x360['all_sales'])
# Out:
# 0.3971031004016887

# %% [markdown]
# ##### АВ

# %%
x360_ab = df_alternative.query('platform =="X360"')
x360_ab.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи АВ', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
x360_ab['critic_score'].corr(x360_ab['all_sales'])
# Out:
# 0.39460224847059305

# %% [markdown]
# ##### Вывод
# Влияние отзывов критиков на продажи начинается после 70 баллов из 100. Все игры, рейтинг которых меньше 70 продаются примерно одинаково. Игры с рейтингом меньше 30 продаются очень мало.
# Возможно, потому что рейтинг начинает давать эффект только при высоких оценках, прямая зависимость между отзывами критиков и продажами всего 0.39.
#
# 🎈 Вывод не изменился. Дополнительные исследования подтвердили предыдущий вывод.

# %% [markdown]
# ##### Влияние отзывов пользователей на продажи

# %%
x360.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи', fontsize = 14)
plt.xlabel('Рейтинг пользователей', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
x360['user_score'].corr(x360['all_sales'])
# Out:
# 0.11595530948624756

# %% [markdown]
# ##### АВ

# %%
x360_ab.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи', fontsize = 14)
plt.xlabel('Рейтинг пользователей', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %%
x360_ab['user_score'].corr(x360_ab['all_sales'])
# Out:
# 0.03832736142896921

# %% [markdown]
# ##### Вывод
# Влияние отзывов пользователей на продажи больше, чем влияние критиков, уже после 5 баллов количество продаж начинают расти. Игры с пользовательской оценкой менее 3 практически не продаются.
# Так же можно отметить, что пользователи реже ставят оценки, если они низкие.
# Прямая зависимость между оценкой пользователей и количеством продаж очень низкая.
#
# 🎈 В целом вывод не изменился, прямая зависимость продаж от рейтинга пользователей в последние пять лет стала еще меньше.

# %% [markdown]
# ### Сравнение результатов и выводов по платформам

# %%
ps3 = df_actual.query('platform =="PS3"')
wii = df_actual.query('platform =="Wii"')
ps4 = df_actual.query('platform =="PS4"')
## pc = df_actual.query('platform =="PC"') Выпал из рейтинга заменяю на 3DS
ds3 = df_actual.query('platform =="3DS"')

# %%
ps3_ab = df_alternative.query('platform =="PS3"')
ps4_ab = df_alternative.query('platform =="PS4"')
xone_ab = df_alternative.query('platform =="XOne"')
## ds3_ab = df_alternative.query('platform =="3DS"') не нужна, так как платформа вышла в 2011 году и вся поместилась в df_actual

# %% [markdown]
# #### Влияние отзывов критиков на продажи

# %% [markdown]
# ##### PS3

# %%
print('Корелляция:', ps3['critic_score'].corr(ps3['all_sales']))

ps3.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи PS3', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.4336947594503307

# %% [markdown]
# ###### АВ 🎈

# %%
print('Корелляция:', ps3['critic_score'].corr(ps3['all_sales']))

ps3.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи PS3 (АВ)', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.4336947594503307

# %% [markdown]
# ##### Wii

# %%
print('Корелляция:', wii['critic_score'].corr(wii['all_sales']))

wii.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи Wii', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

#альтернативной выборки нет, так как Wii не вошла в топ 5
# Out:
# Корелляция: 0.1775598880608996

# %% [markdown]
# ##### PS4

# %%
print('Корелляция:', ps4['critic_score'].corr(ps4['all_sales']))

ps4.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи PS4', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.40656790206178095

# %% [markdown]
# ###### АВ 🎈

# %%
print('Корелляция:', ps4_ab['critic_score'].corr(ps4_ab['all_sales']))

ps4_ab.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи PS4 (АВ)', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.40656790206178095

# %% [markdown]
# **PC**

# %% [markdown]
# pc_ = df_actual.query('platform =="PC"')
# pc_ab = df_alternative.query('platform =="PC"')
#
# print('Корелляция:', pc['critic_score'].corr(pc['all_sales']))
#
# pc.plot(x='critic_score', y='all_sales', kind='scatter')
# plt.title('Влияние отзывов критиков на продажи PC', fontsize = 14)
# plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
# plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# **АВ** 🎈

# %% [markdown]
# print('Корелляция:', pc_ab['critic_score'].corr(pc_ab['all_sales']))
#
# pc_ab.plot(x='critic_score', y='all_sales', kind='scatter')
# plt.title('Влияние отзывов критиков на продажи PC (АВ)', fontsize = 14)
# plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
# plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### XOne 🎈
# Добавляю платформу Xone, вошедшую в топ-5 за последние 5 лет

# %%
print('Корелляция:', xone_ab['critic_score'].corr(xone_ab['all_sales']))

xone_ab.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи PC', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.4169983280084017

# %% [markdown]
# ##### 3DS 🎈
# Добавляю появившуюся после правок платформу 3DS

# %%
print('Корелляция:', ds3['critic_score'].corr(ds3['all_sales']))

ds3.plot(x='critic_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов критиков на продажи 3DS', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.3494009303924131

# %% [markdown]
# #### Вывод
# В целом зависимость продаж от мнения критиков совпадает по всем платформам, кроме Wii. Корелляция по Wii самая низкая  - 0.18, можно предположить, что продажи для этой платформы зависят от чего-то еше сильнее, чем на других платформах. Так же стоит отметить, что у Wii наблюдается резкий спад продаж после 2009 года.
# Для PS3 и PS4 прямая зависимость от оценки критиков выше, чем по остальным платформам.
#
# 🎈 Полученные в ходе дополнительного исследования данные подтверждают уже имеющиеся.

# %% [markdown]
# #### Влияние отзывов пользователей на продажи

# %% [markdown]
# ##### PS3

# %%
print('Корелляция:', ps3['user_score'].corr(ps3['all_sales']))

ps3.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи PS3', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.12584269665485215

# %% [markdown]
# ###### АВ 🎈

# %%
print('Корелляция:', ps3_ab['user_score'].corr(ps3_ab['all_sales']))

ps3_ab.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи PS3', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.010779729319038044

# %% [markdown]
# ##### Wii

# %%
print('Корелляция:', wii['user_score'].corr(wii['all_sales']))
wii.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи Wii', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.11241436067003167

# %% [markdown]
# ##### PS4

# %%
print('Корелляция:', ps4['user_score'].corr(ps4['all_sales']))

ps4.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи PS4', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: -0.031957110204556424

# %% [markdown]
# ###### АВ 🎈

# %%
print('Корелляция:', ps4_ab['user_score'].corr(ps4_ab['all_sales']))

ps4_ab.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи PS3', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: -0.031957110204556424

# %% [markdown]
# ##### PC

# %% [markdown]
# print('Корелляция:', pc['user_score'].corr(pc['all_sales']))
#
# pc.plot(x='user_score', y='all_sales', kind='scatter')
# plt.title('Влияние отзывов пользователей на продажи PC', fontsize = 14)
# plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
# plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# ##### 3DS

# %%
print('Корелляция:', ds3['user_score'].corr(ds3['all_sales']))

ds3.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи 3DS', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: 0.22480798039571082

# %% [markdown]
# ##### XOne

# %%
print('Корелляция:', xone_ab['user_score'].corr(xone_ab['all_sales']))

xone_ab.plot(x='user_score', y='all_sales', kind='scatter')
plt.title('Влияние отзывов пользователей на продажи PS3', fontsize = 14)
plt.xlabel('Рейтинг критиков', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);
# Out:
# Корелляция: -0.06892505328279414

# %% [markdown]
# #### Вывод
# Прямая зависимость между оценкой пользователей и продажами слабая, в случае с PS4, **XOne** и PC - отрицательная, возможно, из-за малого количества оценок.
# При высоких оценнках пользователей продажи игр возрастают. На графике видно, что для PS3 зависимость боле высокая, чем по другим платформам.
#
# 🎈Дополнительные исследования подтвердили имеющийся вывод.

# %% [markdown]
# ### Оценка самых прибыльных жанров

# %% [markdown]
# Смотрю, какое количество игр в каком жанре выпущено за весь исследуемый период и отдельной таблицей начиная с 2006 года.

# %%
df.pivot_table(index='genre', values ='name', aggfunc = 'count').sort_values(by='name', ascending = False)
# Out:
#               name
# genre
# Action        3369
# Sports        2347
# Misc          1750
# Role-Playing  1498
# Shooter       1323
# Adventure     1303
# Racing        1247
# Platform       887
# Simulation     873
# Fighting       849
# Strategy       683
# Puzzle         580

# %%
df_actual.pivot_table(index='genre', values ='name', aggfunc = 'count').sort_values(by='name', ascending = False)
# выпуск игр начиная с 2006 года
# Out:
#               name
# genre
# Action        1717
# Sports         868
# Misc           691
# Shooter        642
# Role-Playing   561
# Adventure      438
# Racing         402
# Simulation     293
# Fighting       247
# Strategy       244
# Platform       200
# Puzzle         118

# %%
df_alternative.pivot_table(index='genre', values ='name', aggfunc = 'count').sort_values(by='name', ascending = False)
# выпуск игр c 2011 года
# Out:
#               name
# genre
# Action        1170
# Role-Playing   397
# Sports         371
# Shooter        341
# Misc           331
# Adventure      295
# Racing         186
# Fighting       147
# Simulation     132
# Platform       112
# Strategy       103
# Puzzle          46

# %% [markdown]
# #### Вывод
# Больше всего было выпущено игр в жанре Action, меньше всего в жанрах Strategy, Platform и Puzzle.
# Начиная с 2006 года количество выпускаемых игр в жанре Platform и Puzzle уменьшается, они начинают занимать две последние строчки рейтинга.
#
#
# 🎈 За последние 5 лет игры в жанре Action не сдали свои позиции, Role-Playing поднялись на 2 место.
# Большая часть игр в жанре Action за 10-летний период вышла за последние 5 лет (1170 к 1717) то есть объем выпуска наращивается.
# Большая часть игр в жанре Role-Playing за 10-летний период вышла за последние 5 лет (397 к 561).
#
# Меньше всего в жанрах Platform, Strategy и Puzzle, так же как и за последнее десятилетие.
#
# Изучаю, какое количество копий было продано в каком жанре игры за весь исследуемый период.

# %% [markdown]
# #### Количство продаж по жанрам

# %%
df.pivot_table(index = 'genre', values = 'all_sales', aggfunc = 'sum').sort_values(by='all_sales', ascending = False)
# Out:
#               all_sales
# genre
# Action          1744.17
# Sports          1331.26
# Shooter         1052.45
# Role-Playing     934.56
# Platform         827.29
# Misc             802.51
# Racing           727.34
# Fighting         447.53
# Simulation       389.97
# Puzzle           242.57
# Adventure        237.59
# Strategy         174.23

# %% [markdown]
# ##### Вывод
# Самые продаваемые игры за весь период исследования в жанре Action, самые маленькие продажи у игр в жанре Strategy.
# Интересное наблюдение, что игры в жанре Adventure занимают шестое место по количеству разработанных игр и предпоследнее по количеству проданных копий.
#
#
# Смотрю, изменилось ли что-то со временем для актуальной выборки **и для альтернативной**.

# %%
df_actual.pivot_table(index = 'genre', values = 'all_sales', aggfunc = 'sum').sort_values(by='all_sales', ascending = False)
# Out:
#               all_sales
# genre
# Action           908.08
# Shooter          686.99
# Sports           663.77
# Misc             399.33
# Role-Playing     335.80
# Racing           245.93
# Platform         195.20
# Fighting         142.18
# Simulation       118.37
# Adventure         76.86
# Strategy          48.36
# Puzzle            24.79

# %%
(df_alternative.
 pivot_table(index = 'genre', values = 'all_sales', aggfunc = 'sum')
 .sort_values(by='all_sales', ascending = False))
# Out:
#               all_sales
# genre
# Action           558.54
# Shooter          408.48
# Sports           237.03
# Role-Playing     227.59
# Misc             138.38
# Racing            88.65
# Platform          86.50
# Fighting          64.37
# Simulation        49.27
# Adventure         40.15
# Strategy          17.71
# Puzzle             8.71

# %% [markdown]
# #### Вывод
# Топ-3 игр не поменялся, но игры в жанре Shooter продаются больше, чем Sport, начиная с 2006 года. Для многих жанрах количество проданных копий растет с увеличением количества выпущенных игр в этом жанре.
#
# Количество продаж игр в жанре Action в 37 раз больше продаж игр в жанре Puzzle.
# Разница в продажах между самыми популярными и самыми непопулярными играми огромная.
#
# 🎈 ТОП-3 игр не изменился в выборке за 5 лет по сравнению с 10-летней выборкой.
# Продажи игр в жанрах Action и Shooter увеличиваются (558.54 к 908.08 и 408.48 к 686.99), а продаж игр в жанре Sports стало меньше. Большая часть продаж игр в жанре Role-Playing пришлась на последние 5 лет из 10 (227.59 к 335.80).
#
# Adventure, Strategy и Puzzle по-прежнему не популярны.
#
# Создаю сводную таблицу Топ-5 жанров.

# %% [markdown]
# ### Оценка количества продаж к количеству изданных игр 🎈
# Выясняю, какое количество копий приходится на выпуск одной игры. Это позволит понять эффективность жанра.

# %%
a = (df_actual
 .pivot_table(index = 'genre', values = ['all_sales','name'], aggfunc = {'all_sales':'sum','name':'count'})) 
a['weighted_average'] = a['all_sales']/a['name']
a.sort_values(by='weighted_average', ascending = False).head()
# Out:
#               all_sales  name  weighted_average
# genre
# Shooter          686.99   642          1.070078
# Platform         195.20   200          0.976000
# Sports           663.77   868          0.764712
# Racing           245.93   402          0.611766
# Role-Playing     335.80   561          0.598574

# %%
b = (df_alternative
 .pivot_table(index = 'genre', values = ['all_sales','name'], aggfunc = {'all_sales':'sum','name':'count'}))

b['weighted_average'] = b['all_sales']/b['name']
b.sort_values(by='weighted_average', ascending = False).head()
# Out:
#               all_sales  name  weighted_average
# genre
# Shooter          408.48   341          1.197889
# Platform          86.50   112          0.772321
# Sports           237.03   371          0.638895
# Role-Playing     227.59   397          0.573275
# Action           558.54  1170          0.477385

# %% [markdown]
# #### Вывод
# Выгоднее всего производить игры в жанре Shooter, Platform, Sports и Role-Playing.
# Shooter и Platform держат первые два места на протяжении 10 лет.
# Action в последние 5 лет вытеснил жанр Racing из топ-5.
#
# Беру топ-5 жанров за последние 5 лет. Так как в целом ничего не поменялось.

# %%
top_5_genre = b.sort_values(by='weighted_average', ascending = False).head()

# %% [markdown]
# ## Портрет пользователя по регионам

# %%
df_actual.head() # вывожу начало таблицы, чтобы освежить память на названия столбцов и данные в них
# Out:
#                         name platform  year_of_release     genre  na_sales  \
# 0                 Wii Sports      Wii             2006    Sports     41.36
# 1             Mario Kart Wii      Wii             2008    Racing     15.68
# 2          Wii Sports Resort      Wii             2009    Sports     15.61
# 3                   Wii Play      Wii             2006      Misc     13.96
# 4  New Super Mario Bros. Wii      Wii             2009  Platform     14.44
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  all_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1     12.76      3.79         3.29          82.0         8.3      E      35.52
# 2     10.93      3.28         2.95          80.0         8.0      E      32.77
# 3      9.18      2.93         2.84          58.0         6.6      E      28.91
# 4      6.94      4.70         2.24          87.0         8.4      E      28.32

# %% [markdown]
# ### Портрет пользователя NA-региона

# %% [markdown]
# #### Топ-5 платформ

# %%
top_5 #Вывожу топ-5 платформ по всем регионам за 10 лет
# Out:
#   platform  all_sales
# 0     X360     963.17
# 1      PS3     939.16
# 2      Wii     907.51
# 3      PS4     314.14
# 4      3DS     259.00

# %%
(df_actual.pivot_table(index = 'platform', values = 'na_sales', aggfunc = 'sum')
 .sort_values(by='na_sales', ascending = False).head())  # Топ-5 платформ по NA за последние 10 лет
# Out:
#           na_sales
# platform
# X360        595.57
# Wii         496.90
# PS3         393.49
# PS4         108.74
# XOne         93.12

# %%
top_5_ab #Вывожу топ-5 платформ по всем регионам за последние 5 лет
# Out:
#   platform  all_sales
# 0      PS3     453.39
# 1     X360     390.56
# 2      PS4     314.14
# 3      3DS     259.00
# 4     XOne     159.32

# %%
(df_alternative.pivot_table(index = 'platform', values = 'na_sales', aggfunc = 'sum')
 .sort_values(by='na_sales', ascending = False).head())  # Топ-5 платформ по NA за последние 5 лет
# Out:
#           na_sales
# platform
# X360        233.53
# PS3         171.62
# PS4         108.74
# XOne         93.12
# 3DS          83.49

# %% [markdown]
# #### Вывод
# X360 занимает первое место среди платформ в Северной Америке и 71% продаж игр для этой платформы по всем регионам приходится на Северную америку.
# PS3 уступает второе место Wii.
# Так же пользователи Северной Америки предпочитают платформу XOne, которая не входит в ТОП-5 платформ по всем регионам.
#
# 🎈 За последние 5 лет Wii ушла из топ-5 списка любимых платформ Северной Америки, возможно, потому что в 2013 году поддержка [Wii](https://ru.wikipedia.org/wiki/Wii) была прекращена. В топ-5 пробилась платформа 3DS. В целом предпочтения американцев совпадают с "общемировыми".

# %% [markdown]
# #### Топ-5 жанров

# %%
top_5_genre #Топ-5 жанров для всех регионов
# Out:
#               all_sales  name  weighted_average
# genre
# Shooter          408.48   341          1.197889
# Platform          86.50   112          0.772321
# Sports           237.03   371          0.638895
# Role-Playing     227.59   397          0.573275
# Action           558.54  1170          0.477385

# %%
na_top_5 = df_actual.pivot_table(index = 'genre', values = 'na_sales', aggfunc = 'sum').sort_values(by='na_sales', ascending = False).head()
# na_top_5['sales_share'] = na_top_5['na_sales']/top_5_genre['all_sales'] не имеет смысла, т.к. топ 5 жанров расчитан за 5 лет
na_top_5 # Топ-5 жанров по NA и доля от всех продаж Топ-5 игр
# Out:
#               na_sales
# genre
# Action          424.83
# Shooter         355.12
# Sports          339.55
# Misc            222.51
# Role-Playing    138.86

# %%
na_top_5_ab = (df_alternative
               .pivot_table(index = 'genre', values = 'na_sales', aggfunc = 'sum')
               .sort_values(by='na_sales', ascending = False).head())
na_top_5_ab['sales_share'] = na_top_5_ab['na_sales']/top_5_genre['all_sales']
na_top_5_ab # Топ-5 жанров по NA и доля от всех продаж Топ-5 игр
# Out:
#               na_sales  sales_share
# genre
# Action          233.92     0.418806
# Shooter         197.13     0.482594
# Sports          110.63     0.466734
# Role-Playing     80.28     0.352740
# Misc             71.42          NaN

# %% [markdown]
# ##### Вывод
# Предпочтения Северной Америки за 10 и за 5 лет не изменились, жанр Misc стал менее популярен, а Role-Playing чуть более популярен.
#
# Почти половина всех продаж приходится на Северную Америку.
# Североамериканский пользователь предпочитает жанр Action, в то время как в мире этот жанр занимает последнюю пятую строчку топа.
# Игры в жанре Platform не вошли в предпочтения пользователей этого региона.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в регионе

# %%
df_actual['rating'] = df_actual['rating'].fillna('Нет рейтинга')
df_actual.tail()
# Out:
#                                name platform  year_of_release       genre  \
# 6416               Aiyoku no Eustia      PSV             2014        Misc
# 6417  Samurai Warriors: Sanada Maru      PS3             2016      Action
# 6418               LMA Manager 2007     X360             2006      Sports
# 6419        Haitaka no Psychedelica      PSV             2016   Adventure
# 6420            Winning Post 8 2016      PSV             2016  Simulation
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 6416       0.0      0.00      0.01          0.0           NaN         NaN
# 6417       0.0      0.00      0.01          0.0           NaN         NaN
# 6418       0.0      0.01      0.00          0.0           NaN         NaN
# 6419       0.0      0.00      0.01          0.0           NaN         NaN
# 6420       0.0      0.00      0.01          0.0           NaN         NaN
#
#             rating  all_sales
# 6416  Нет рейтинга       0.01
# ...

# %%
(df_actual.pivot_table(index = 'rating', values = 'na_sales', aggfunc = 'sum')
.plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в NA', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# Меньше всего продаж игр с рейтингом EC (Для детей младшего возраста).
# Больше всего продаж с рейтингом М (Для взрослых), Е (Для всех) и T (для подростков от 13 лет).
# 🎈 Игры с отсутствующим рейтингом так же составляют большой объем продаж.

# %%
df_alternative['rating'] = df_alternative['rating'].fillna('Нет рейтинга')
df_alternative.head()
# Out:
#                              name platform  year_of_release         genre  \
# 0              Grand Theft Auto V      PS3             2013        Action
# 1              Grand Theft Auto V     X360             2013        Action
# 2  Call of Duty: Modern Warfare 3     X360             2011       Shooter
# 3       Call of Duty: Black Ops 3      PS4             2015       Shooter
# 4             Pokemon X/Pokemon Y      3DS             2013  Role-Playing
#
#    na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 0      7.02      9.09      0.98         3.96          97.0         8.2
# 1      9.66      5.14      0.06         1.41          97.0         8.1
# 2      9.04      4.24      0.13         1.32          88.0         3.4
# 3      6.03      5.86      0.36         2.38           NaN         NaN
# 4      5.28      4.19      4.35         0.78           NaN         NaN
#
#          rating  all_sales
# 0             M      21.05
# 1             M      16.27
# ...

# %%
(df_alternative.pivot_table(index = 'rating', values = 'na_sales', aggfunc = 'sum')
.plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в NA (АВ)', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# 🎈 За последнгие 5 лет игры с рейтингом EC (Для детей младшего возраста) вообще перестали продаваться или такой рейтинг перестал присваиваться.
# Больше всего продаж с рейтингом М (Для взрослых) и Е (Для всех).
# Доля продаж остальных игр сопоставима с продажами игр без рейтинга.

# %%
df_alternative.query('rating =="Нет рейтинга"').tail(15)
# Out:
#                                                    name platform  \
# 3610                                   Prison Architect     XOne
# 3611                Hakuoki: Reimeiroku - Omouhase Kara      PSV
# 3612                                  Hanasaku Manimani      PSV
# 3613  Fujiko F. Fujio Characters: Great Assembly! Sl...      3DS
# 3615                      Tsukigime Ranko's Longest Day      PS3
# 3616                   Aikatsu Stars! My Special Appeal      3DS
# 3618                               Kyoukai no Shirayuki      PSV
# 3619                                          7'scarlet      PSV
# 3621                       Dynasty Warriors: Eiketsuden      PS3
# 3624                              The Longest 5 Minutes      PSV
# 3626                                   Strawberry Nauts      PSV
# 3627                                   Aiyoku no Eustia      PSV
# 3628                      Samurai Warriors: Sanada Maru      PS3
# ...

# %%
df_alternative.query('rating =="EC"') # за 5 лет не было продано ни одной игры с рейтингом EC
# Out:
# Empty DataFrame
# Columns: [name, platform, year_of_release, genre, na_sales, eu_sales, jp_sales, other_sales, critic_score, user_score, rating, all_sales]
# Index: []

# %% [markdown]
# #### Возможные причины отсутствия рейтинга 🎈
# * Сайт, с которого брали данные о рейтинге, не хранил данные о рейтингах для этих игр. т.к. отсутствуют рейтинги критиков и пользователей.
# * Очень маленькие продажи, поэтому информацию о рейтингах не собирали для некоторых игр.
# * Получение рейтинга ESRB - дело добровольное, он присваивается только по заявке создателя игры и предназначен для рынка [США, Канады и Мексики](https://okdk.ru/chto-oznachajut-rejtingi-videoigr-rukovodstvo-po-esrb-i-pegi/). Эти игры, возможно, изначально не предполагалось продавать там.

# %% [markdown]
# #### Портрет пользователя из NA-региона. Вывод 🎈
#
# За 10-летний период: Взрослый или подросток, предпочитает игры в жанре Action, Shooter и Sport. Предпочитает приставки X360, Wii и PS3.
#
# За 5-летний период: Взрослый или "человек без возраста", предпочитает игры в жанре Action, Shooter и Sport. Предпочитает приставки X360, PS3 и PS4.
#
# Поднятие в рейтинге PS3 скорее всего связано не с тем, что у них лучше пошли продажи, а с тем, что Wii перестала продаваться.

# %% [markdown]
# ### Портрет пользователя EU-региона

# %% [markdown]
# #### Топ-5 платформ

# %%
top_5 #Вывожу топ-5 платформ по всем регионам за 10 лет
# Out:
#   platform  all_sales
# 0     X360     963.17
# 1      PS3     939.16
# 2      Wii     907.51
# 3      PS4     314.14
# 4      3DS     259.00

# %%
(df_actual.pivot_table(index = 'platform', values = 'eu_sales', aggfunc = 'sum')
 .sort_values(by='eu_sales', ascending = False).head()) # Топ-5 платформ по Европе за 10 лет
# Out:
#           eu_sales
# platform
# PS3         329.80
# X360        270.33
# Wii         262.21
# PS4         141.09
# PC          102.33

# %%
top_5_ab #Вывожу топ-5 платформ по всем регионам за 5 лет
# Out:
#   platform  all_sales
# 0      PS3     453.39
# 1     X360     390.56
# 2      PS4     314.14
# 3      3DS     259.00
# 4     XOne     159.32

# %%
(df_alternative.pivot_table(index = 'platform', values = 'eu_sales', aggfunc = 'sum')
 .sort_values(by='eu_sales', ascending = False).head()) # Топ-5 платформ по Европе за 5 лет
# Out:
#           eu_sales
# platform
# PS3         165.69
# PS4         141.09
# X360        119.54
# 3DS          61.48
# PC           58.71

# %% [markdown]
# Наиболее популярная платформа в Европе - PS3 на протяжении 10 лет.
# Треть всех игр для этой платформы покупается пользователями в Европе.
# За ней идет PS4 и X360.
# Так же в Топ-5 попали игры для PC.
#
# В Топ-5 не попала популярная платформа XOne.

# %% [markdown]
# #### Топ-5 жанров

# %%
top_5_genre #Топ-5 жанров для всех регионов
# Out:
#               all_sales  name  weighted_average
# genre
# Shooter          408.48   341          1.197889
# Platform          86.50   112          0.772321
# Sports           237.03   371          0.638895
# Role-Playing     227.59   397          0.573275
# Action           558.54  1170          0.477385

# %%
eu_top_5 = (df_actual.pivot_table(index = 'genre', values = 'eu_sales', aggfunc = 'sum')
            .sort_values(by='eu_sales', ascending = False).head())

##eu_top_5['sales_share'] = eu_top_5['eu_sales']/top_5_genre['all_sales']
eu_top_5 #Топ-5 жанров для EU и для продаж от всех продаж Топ-5 игр
# Out:
#          eu_sales
# genre
# Action     306.01
# Shooter    234.19
# Sports     222.98
# Misc       112.81
# Racing     100.34

# %%
eu_top_5_ab = (df_alternative.pivot_table(index = 'genre', values = 'eu_sales', aggfunc = 'sum')
            .sort_values(by='eu_sales', ascending = False).head())

eu_top_5_ab['sales_share'] = eu_top_5_ab['eu_sales']/top_5_genre['all_sales']
eu_top_5_ab #Топ-5 жанров для EU и для продаж от всех продаж Топ-5 игр
# Out:
#               eu_sales  sales_share
# genre
# Action          201.22     0.360261
# Shooter         150.18     0.367656
# Sports           88.54     0.373539
# Role-Playing     60.53     0.265961
# Racing           41.14          NaN

# %% [markdown]
# Топ-3 популярных жанров в Европе: Action, Shooter и Sport, это соответствует "общемировым" предпочтениям.
# Так же пользователи из Европы предпочитают жанр Racing, который не попал в Топ-5 жанров по всем регионам и не так популярен в Северной Америке.
#
# За последние 5 лет из топ-5 выпали игры в жанре Misc и появились Role-Playing, в остальном наблюдается стабильность.
# За 5 лет из 10 было куплено 2/3 игр в жанре Action, и 60% игр а жанре Shooter, т.е. продажи растут.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в регионе

# %%
(df_actual.pivot_table(index = 'rating', values = 'eu_sales', aggfunc = 'sum')
 .plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в EU', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# Больше всего продаж на срезе в 10 лет в Европе приходится на игры с рейтингом М (Для взрослых), Е (Для всех) и Т(Подросткам от 13 лет).

# %%
(df_alternative.pivot_table(index = 'rating', values = 'eu_sales', aggfunc = 'sum')
 .plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в EU (АВ)', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# На срезе в 5 лет пользователи из Европы так же предпочитают покупать игры с рейтингом М ("Для взрослых") и Е (Для всех). Выросла доля игр, для которых рейтинг не определен и ее продажи даже больше, чем у игр для подростков.

# %% [markdown]
# #### Портрет пользователя из Европы. Вывод
#
# На срезе в 10 лет: Взрослый или подросток, в основном предпочитает играть на приставках Ps3, X360 и Wii, но так же не против использовать копьютер. Любимые жанры совпадают с "общемировыми" предпочтениями: Action, Shooter, Sport.
#
# На срезе в 5 лет: Взрослый или "человек неопределенного возрата", предпочитает играть на приставках PS3, PS4 и X360, так же использует компьютер для игр и предпочитает жанры: Action, Shooter, Sport. Новое увлечение -  игры в жанре Role-Playing.
#
# В целом наблюдается стабильный спрос на протяжении 10 лет, однако возраст пользователя становится более неопределенным, так как все больше пользователей отдают предпочтения нейтральным играм без кровищи для всех возрастов.

# %% [markdown]
# ### Портрет пользователя JP-региона

# %% [markdown]
# #### Топ-5 платформ

# %%
top_5 #Вывожу топ-5 платформ по всем регионам
# Out:
#   platform  all_sales
# 0     X360     963.17
# 1      PS3     939.16
# 2      Wii     907.51
# 3      PS4     314.14
# 4      3DS     259.00

# %%
(df_actual.pivot_table(index = 'platform', values = 'jp_sales', aggfunc = 'sum')
 .sort_values(by='jp_sales', ascending = False).head()) # Топ-5 платформ в Японии
# Out:
#           jp_sales
# platform
# 3DS         100.67
# PS3          80.19
# Wii          69.33
# PSV          21.91
# PS4          15.96

# %% [markdown]
# Наиболее популярная платформа в Японии - 3DS, половина всех игр для этой платформы покупается в Японии (Производитель - Nintendo, японская компания).
# Так же популярна приставка PSV, это тоже портативная консоль как и 3DS.
# Рынок Японии в несколько раз меньше рынка Северной Америки.

# %%
top_5_ab
# Out:
#   platform  all_sales
# 0      PS3     453.39
# 1     X360     390.56
# 2      PS4     314.14
# 3      3DS     259.00
# 4     XOne     159.32

# %%
(df_alternative.pivot_table(index = 'platform', values = 'jp_sales', aggfunc = 'sum')
 .sort_values(by='jp_sales', ascending = False).head())
# Out:
#           jp_sales
# platform
# 3DS         100.67
# PS3          50.17
# PSV          21.91
# PS4          15.96
# WiiU         13.01

# %% [markdown]
# 🎈 На срезе в 5 лет пользователи из Японии по прежнему предпочитают свою консоль 3DS. Так же как и в других регионах по той же причине из рейтинга ушла Wii и появилась WiiU следующего поколения.
# Все еще популярна PSV.
#
# 3DS, PSV и WiiU судя по картинкам в интернете - портативные консоли, значит, для пользователей из Японии важен размер и возможность переноски устройства.

# %% [markdown]
# #### Топ-5 жанров

# %%
top_5_genre #Топ-5 жанров для всех регионов
# Out:
#               all_sales  name  weighted_average
# genre
# Shooter          408.48   341          1.197889
# Platform          86.50   112          0.772321
# Sports           237.03   371          0.638895
# Role-Playing     227.59   397          0.573275
# Action           558.54  1170          0.477385

# %%
jp_top_5 = (df_actual.pivot_table(index = 'genre', values = 'jp_sales', aggfunc = 'sum')
            .sort_values(by='jp_sales', ascending = False).head())

##jp_top_5['sales_share'] = jp_top_5['jp_sales']/top_5_genre['all_sales']
jp_top_5 # Топ-5 жанров для Японии и доля продаж от всех продаж Топ-5 игр за 10 лет
# Out:
#               jp_sales
# genre
# Role-Playing     79.38
# Action           73.87
# Sports           31.17
# Misc             27.04
# Platform         22.58

# %% [markdown]
# На срезе в 10 лет: Наиболее популярный жанр в Японии - Role-Playing. В Японии не популярны игры в жанре Shooter.

# %%
jp_top_5_ab = (df_alternative.pivot_table(index = 'genre', values = 'jp_sales', aggfunc = 'sum')
            .sort_values(by='jp_sales', ascending = False).head())

jp_top_5_ab['sales_share'] = jp_top_5_ab['jp_sales']/top_5_genre['all_sales']
jp_top_5_ab # Топ-5 жанров для Японии и доля продаж от всех продаж Топ-5 игр для 5 лет
# Out:
#               jp_sales  sales_share
# genre
# Role-Playing     67.60     0.297025
# Action           58.70     0.105095
# Misc             15.65          NaN
# Shooter          12.00     0.029377
# Platform         11.72     0.135491

# %% [markdown]
# На срезе в 5 лет: Наиболее популярный жанр в Японии - Role-Playing, однако вклад Японии в покупку игр не превышает 30% в жанре Role-Playing от всех продаж в этом жанре.
# Становится популярным жанр Shooter и уходят из топ-5 игры в жанре Sports.

# %% [markdown]
# #### Влияние рейтинга ESRB на продажи в регионе

# %%
(df_actual.pivot_table(index = 'rating', values = 'jp_sales', aggfunc = 'sum')
.plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в Ja', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# 🎈 На срезе в 10 лет: Больше всего продаж в Японии приходится на игры, для которых нет рейтинга ESRB, далее идут игры с рейтингом Е (Для всех), Т(Подросткам от 13 лет) и М (Для взрослых).
# Я думаю, что в Японии так популярны игры без рейтинга потому что, это игры, выпущенные в Японии для Японии, соответственно им не нужно было получать рейтинг ESRB.

# %%
(df_alternative.pivot_table(index = 'rating', values = 'jp_sales', aggfunc = 'sum')
.plot(kind = 'bar', figsize = (8,4)))
plt.title('Влияние ESRB на продажи в Ja (АВ)', fontsize = 14)
plt.xlabel('Рейтинг ESRB', color = 'green', fontsize = 14)
plt.ylabel('Проданные копии, млн', color = 'green', fontsize = 14);

# %% [markdown]
# 🎈 На срезе в 5 лет: Игры без рейтинга - самые популярные в Японии, предполагаю, что специфичный японский рынок замкнулся на игры собственного производства, а игры, выпущенные для Америки стали менее популярны. Возможно, потому что своих игр стало больше, а вкусы сильно отличаются от европейских и американских.

# %% [markdown]
# #### Портрет пользователя из Ja-региона. Вывод
# Портрет пользователя из Ja-региона
# Срез в 10 лет: У пользователя из Японии нет четкого возрастного идентификатора, это может быть как ребенок, так и взрослый.
# Пользователь предпочитает игры в жанре Role-Playing, Action и Sport. Предпочитает приставки 3DS, PS3 и  Wii.
#
# Срез в 5 лет: Пользователь неопределенного возраста. Возраст не играет значения. Пользователь предпочитает игры в жанре Role-Playing, Action и Misc	. Предпочитает приставки 3DS, PS3 и PSV. Для пользователя из Японии является важной преимуществом при выборе консоли - ее портативность.

# %% [markdown]
# ### Вывод о портрете пользователя из разных регионов
# Пользователи из Северной Америки и Европы ближе друг к другу по предпочтениям как в выборе платформ, так и в выборе жанров игр.
# Пользователи из Северной Америки предпочитают играть исключительно на приставках. Пользователи из Европы так же используют для игры компьютеры. Самые любимы жанры это: Action, Shooter и Sport. Пользователи Северной Америки и Европы больше всего покупают игры для взрослых и для всех возрастов, так же интересуются играми для детей от 13 лет.
#
# Японский пользователь предпочитает играть на "родных" портативных игровых системах 3DS и других приставках. Японский пользователь делает выбор в пользу ролевых игр. "Стрелялки" попали в Топ-5 игр только в последние 5 лет, самые любимые жанры: Role-Playing, Action и Sport. Японские пользователи в первую очередь интересуются играми для всех возрастов и и для портативных приставок. За последние 5 лет японских пользвателей перестали интересовать игры в жанре Sports. Так же пользователи из этого региона предпочитают игры, выпущенные не для американского рынка.
#
# Самый "играющий" регион - это Северная Америка.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Проверка гипотезы "Средние пользовательские рейтинги платформ Xbox One и PC одинаковые"
#
# Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC разные.
# Гипотеза является двусторонней, так как рейтинг может быть как больше, так и меньше. Проверить гипотезу можно с помощью t-теста для гипотезы о равенстве двух генеральных совокупностей.
#
# Первая совокупность - это данные о рейтинге по платформе Xbox One.
# Вторая совокупность - это данные о рейтинге по платформе PC.

# %% [markdown]
# Так как в столбце user_score есть пропущенные значения, то это может помешать проверке гипотезы.
# Удаляю все пропущенные значения из этого столбца.

# %%
df_actual = df_actual.dropna(subset = ['user_score'])
df_alternative = df_alternative.dropna(subset = ['user_score'])

# %% [markdown]
# Создаю две выборки для проверки.

# %%
xboxone_user_score  = df_actual.query('platform == "XOne"')['user_score']
pc_user_score = df_actual.query('platform == "PC"')['user_score']

xboxone_user_score_ab  = df_alternative.query('platform == "XOne"')['user_score'] # для альтернативного варианта в 5 лет
pc_user_score_ab = df_alternative.query('platform == "PC"')['user_score']

# %% [markdown]
# Проверяю равенство дисперсий.

# %%
print(np.var(xboxone_user_score,ddof=1))
print(np.var(pc_user_score,ddof=1))
# Out:
# 1.9069968429360702
# 2.30428209775906

# %%
print(np.var(xboxone_user_score_ab, ddof=1)) # для альтернативного варианта в 5 лет
print(np.var(pc_user_score_ab,ddof=1))
# Out:
# 1.9069968429360702
# 2.5666345404984403

# %% [markdown]
# Так как значения пользовательского рейтинга лежат между 0 и 10, то можно считать, что разница между дисперсиями достаточно большая, чтобы параметр equal_var был равен False.
# Alpha выбираю 1%, так как значения расположены очень близко и редкая игра получает оценки в большом диапазоне.

# %%
results = st.ttest_ind(xboxone_user_score,pc_user_score, equal_var = False)
alpha = 0.01
print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.010195606278101961
# Не получилось отвергнуть нулевую гипотезу

# %%
results = st.ttest_ind(xboxone_user_score_ab, pc_user_score_ab, equal_var = False)
alpha = 0.01
print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.6821750204106906
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# ### Вывод
# 🎈На 5-летней выборке гипотезу о том, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые, отвергнуть не получилось.

# %% [markdown]
# ### Проверка гипотезы "Средние пользовательские рейтинги жанров Action и Sports разные"
#
# Нулевая гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
# Альтернативная гипотеза: Средние пользовательские рейтинги платформ Xbox One и PC разные.
# Гипотеза является двусторонней, так как рейтинг может быть как больше, так и меньше. Проверить гипотезу можно с помощью t-теста для гипотезы о равенстве двух генеральных совокупностей.
#
# Первая совокупность - это данные о рейтинге по платформе Xbox One.
# Вторая совокупность - это данные о рейтинге по платформе PC.

# %% [markdown]
# Создаю две выборки для проверки.

# %%
action_user_score  = df_actual.query('genre == "Action"')['user_score']
sports_user_score = df_actual.query('genre == "Sports"')['user_score']

action_user_score_ab  = df_alternative.query('genre == "Action"')['user_score']  # для альтернативного варианта в 5 лет
sports_user_score_ab = df_alternative.query('genre == "Sports"')['user_score']

# %% [markdown]
# Проверяю равенство дисперсий для определения, нужно ли будет использовать параметр equal_var.

# %%
print(np.var(action_user_score,ddof=1))
print(np.var(sports_user_score,ddof=1))
# Out:
# 1.7395719738593256
# 2.8631199467595567

# %%
print(np.var(action_user_score_ab,ddof=1)) # для альтернативного варианта в 5 лет
print(np.var(sports_user_score_ab,ddof=1))
# Out:
# 1.781999554246457
# 2.894071447078636

# %% [markdown]
# Разница между дисперсиями большая.
# Так же как и в проверке предыдущей гипотезы, устанавливаю параметр equal_var - False, и ставлю значение alpha  - 1%.

# %%
results = st.ttest_ind(action_user_score, sports_user_score, equal_var = False)
alpha = 0.01
print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  4.780956913675287e-14
# Отвергаем нулевую гипотезу

# %%
results = st.ttest_ind(action_user_score_ab, sports_user_score_ab, equal_var = False)
alpha = 0.01
print('p-значение: ', results.pvalue)

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  3.1604840664600617e-18
# Отвергаем нулевую гипотезу

# %% [markdown]
# На пятилетней выборке гипотеза о том, что средние пользовательские рейтинги жанров Action и Sport равны, отвергнута, следовательно они не равны.

# %% [markdown]
# ###  Вывод
# Средние пользовательские рейтинги жанров Action и Sports разные.

# %% [markdown]
# ## Вывод
#
# **Задача исследования: Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.**
#
# В ходе исследования выявленны закономерности:
# Самые успешные игры выпущены на английском языке для приставок PS3, X360 и PS4. Самый активный потребитель игр - это NA-регион и EU-регион. Самые популярные жанры в этих регионах: Action, Shooter, Sports.
# Игры в этих жанрах так же и выпускаются в большем количестве.
#
# Самые успешные жанры:
# * Shooter - на 1 игру в среднем приходится 1.1 миллион продаж.
# * Platform - на 1 игру в среднем приходится 1 миллион продаж.
# * Sport - на 1 игру в среднем приходится 0,7 миллионов продаж.
#
# Для Ja-ругиона нужно учитывать региональную специфику, так как они предпочитают игры в жанрах Role-playing, Action и Misc. Пользователи Ja-региона предпочитают портативные консоли, но сам рынок небольшой. Так же регион специфический, здесь много продаж игр без рейтинга, которые, скорее всего являются локальными, созданными под азиатский рынок. Реклама должна создаваться точечно и только на Ja-регион.
#
# Не следует тратить деньги на рекламу игр для приставок, которые уже вышли из употребления.
#
# В последние 5 лет наблюдается три направления продаж по рейтингу ESRB:
# * покупается много игр с рейтингом 18+.
# * нейтральные игры, которые походят для всех возрастов.
# * игры без рейтинга (возможно, не предназначенные для рынка США).
#
# ### Рекомендации
# При ограниченном бюджете:
# Универсальным продуктом для всех регионов являются игры в жанре Action для приставок PS3.
# Наиболее привлекательный регион - NA, так как там самая большая аудитория.
# Так же следует провести дополнительное исследование конкурентов и удовлетворенности спроса в этом регионе.
