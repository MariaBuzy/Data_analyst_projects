# %% [markdown]
# # Анализ убытков приложения ProcrastinatePRO+

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-задачи" data-toc-modified-id="Описание-задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание задачи</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Библиотеки" data-toc-modified-id="Библиотеки-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Библиотеки</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Таблица-visits" data-toc-modified-id="Таблица-visits-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Таблица visits</a></span></li><li><span><a href="#Таблица-orders" data-toc-modified-id="Таблица-orders-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Таблица orders</a></span></li><li><span><a href="#Таблица-costs" data-toc-modified-id="Таблица-costs-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Таблица costs</a></span></li><li><span><a href="#Вывод-&quot;Предобработка-данных&quot;" data-toc-modified-id="Вывод-&quot;Предобработка-данных&quot;-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Вывод "Предобработка данных"</a></span></li></ul></li><li><span><a href="#Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии" data-toc-modified-id="Функции-для-расчета-и-анализа-LTV,-ROI,-удержания-и-конверсии-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Функции для расчета и анализа LTV, ROI, удержания и конверсии</a></span><ul class="toc-item"><li><span><a href="#Функция-для-расчета-ltv-и-roi" data-toc-modified-id="Функция-для-расчета-ltv-и-roi-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Функция для расчета ltv и roi</a></span></li><li><span><a href="#Функция-для-сглаживания-фрейма" data-toc-modified-id="Функция-для-сглаживания-фрейма-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Функция для сглаживания фрейма</a></span></li><li><span><a href="#Функция-для-визуализации-LTV-и-ROI" data-toc-modified-id="Функция-для-визуализации-LTV-и-ROI-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Функция для визуализации LTV и ROI</a></span></li><li><span><a href="#Функция-для-расчета-удержания" data-toc-modified-id="Функция-для-расчета-удержания-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Функция для расчета удержания</a></span></li><li><span><a href="#Функция-для-визуализации-удержания" data-toc-modified-id="Функция-для-визуализации-удержания-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Функция для визуализации удержания</a></span></li><li><span><a href="#Функция-для-расчета-конверсии" data-toc-modified-id="Функция-для-расчета-конверсии-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Функция для расчета конверсии</a></span></li><li><span><a href="#Функция-для-визуализации-конверсии" data-toc-modified-id="Функция-для-визуализации-конверсии-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Функция для визуализации конверсии</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Профили пользователей</a></span></li><li><span><a href="#Минимальная-и-максимальная-даты-привлечения-пользователя." data-toc-modified-id="Минимальная-и-максимальная-даты-привлечения-пользователя.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Минимальная и максимальная даты привлечения пользователя.</a></span></li><li><span><a href="#Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?" data-toc-modified-id="Из-каких-стран-приходят-посетители?-Какие-страны-дают-больше-всего-платящих-пользователей?-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Какими-устройствами-пользуются?-С-каких-устройств-чаще-всего-заходят-платящие-пользователи?" data-toc-modified-id="Какими-устройствами-пользуются?-С-каких-устройств-чаще-всего-заходят-платящие-пользователи?-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Какими устройствами пользуются? С каких устройств чаще всего заходят платящие пользователи?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?" data-toc-modified-id="По-каким-рекламным-каналам-шло-привлечение-пользователей?-Какие-каналы-приносят-больше-всего-платящих-пользователей?-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.5.1"><span class="toc-item-num">6.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод-&quot;Исследовательский-анализ-данных&quot;" data-toc-modified-id="Вывод-&quot;Исследовательский-анализ-данных&quot;-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Вывод "Исследовательский анализ данных"</a></span></li></ul></li><li><span><a href="#Расходы-на-маркетинг" data-toc-modified-id="Расходы-на-маркетинг-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Расходы на маркетинг</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Расходы-на-маркетинг&quot;" data-toc-modified-id="Вывод-&quot;Расходы-на-маркетинг&quot;-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Вывод "Расходы на маркетинг"</a></span></li></ul></li><li><span><a href="#Расчет-среднего-CAC" data-toc-modified-id="Расчет-среднего-CAC-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Расчет среднего CAC</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Вывод-&quot;Расчеты-на-CAC&quot;" data-toc-modified-id="Вывод-&quot;Расчеты-на-CAC&quot;-8.0.1"><span class="toc-item-num">8.0.1&nbsp;&nbsp;</span>Вывод "Расчеты на CAC"</a></span></li></ul></li></ul></li><li><span><a href="#Оценка-окупаемости-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценка-окупаемости-рекламы-для-привлечения-пользователей-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Оценка окупаемости рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Горизонт-и-момент-анализа" data-toc-modified-id="Горизонт-и-момент-анализа-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Горизонт и момент анализа</a></span></li><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Общая-окупаемость-рекламы&quot;" data-toc-modified-id="Вывод-&quot;Общая-окупаемость-рекламы&quot;-9.2.1"><span class="toc-item-num">9.2.1&nbsp;&nbsp;</span>Вывод "Общая окупаемость рекламы"</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-устройствам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-устройствам-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по устройствам</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-устройствам&quot;" data-toc-modified-id="Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-устройствам&quot;-9.3.1"><span class="toc-item-num">9.3.1&nbsp;&nbsp;</span>Вывод "Окупаемость рекламы с разбивкой по устройствам"</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-странам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-странам-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по странам</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-странам&quot;" data-toc-modified-id="Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-странам&quot;-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Вывод "Окупаемость рекламы с разбивкой по странам"</a></span></li></ul></li><li><span><a href="#Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам" data-toc-modified-id="Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>Окупаемость рекламы с разбивкой по рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам&quot;" data-toc-modified-id="Вывод-&quot;Окупаемость-рекламы-с-разбивкой-по-рекламным-каналам&quot;-9.5.1"><span class="toc-item-num">9.5.1&nbsp;&nbsp;</span>Вывод "Окупаемость рекламы с разбивкой по рекламным каналам"</a></span></li></ul></li><li><span><a href="#Выводы-&quot;LTV,-CAC,-ROI&quot;" data-toc-modified-id="Выводы-&quot;LTV,-CAC,-ROI&quot;-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Выводы "LTV, CAC, ROI"</a></span></li><li><span><a href="#Конверсия" data-toc-modified-id="Конверсия-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Конверсия</a></span></li><li><span><a href="#Удержание" data-toc-modified-id="Удержание-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Удержание</a></span><ul class="toc-item"><li><span><a href="#Вывод-&quot;Конверсия-и-удержание&quot;" data-toc-modified-id="Вывод-&quot;Конверсия-и-удержание&quot;-9.8.1"><span class="toc-item-num">9.8.1&nbsp;&nbsp;</span>Вывод "Конверсия и удержание"</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-9.9"><span class="toc-item-num">9.9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод-по-исследованию" data-toc-modified-id="Вывод-по-исследованию-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Вывод по исследованию</a></span></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></div>

# %% [markdown]
# ## Описание задачи
#
# У приложения Procrastinate Pro+ несколько прошлых месяцев постоянно несет убытки - в привлечение пользователей была вложена куча денег, а толку никакого. Нужно разобораться в причинах.
#
# Есть лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
#
# Необходимо выяснить:
# * Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# * Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# * По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?
#
# * Сколько денег потратили на рекламу? Всего / на каждый источник / по времени?
# * Сколько в среднем стоило привлечение одного покупателя из каждого источника?
#
# Нужен анализ:
# * общей окупаемости рекламы,
# * окупаемости рекламы с разбивкой по устройствам,
# * окупаемости рекламы с разбивкой по странам,
# * окупаемости рекламы с разбивкой по рекламным каналам.
#
# Нужен ответ на вопросы:
# * Окупается ли реклама, направленная на привлечение пользователей в целом?
# * Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
# * Чем могут быть вызваны проблемы окупаемости? Изучите конверсию и удержание с разбивкой по устройствам, странам, рекламным каналам.
#
#
# ## Описание данных
#
# Момент анализа 1 ноября 2019 года.
# Горизонт анализа 14 дней.
#
#
# * /datasets/visits_info_short.csv **сессии**
# * /datasets/orders_info_short.csv **заказы**
# * /datasets/costs_info_short.csv  **стоимость рекламы**
#
# Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#
# * User Id — уникальный идентификатор пользователя,
# * Device — категория устройства пользователя,
# * Session start — дата и время начала сессии,
# * Session End — дата и время окончания сессии,
# * Channel — идентификатор рекламного источника, из которого пришел пользователь,
# * Region - страна пользователя.
#
# Таблица orders_log_short (информация о заказах):
#
# * User Id — уникальный id пользователя, который сделал заказ,
# * Event Dt — дата и время покупки,
# * Revenue — выручка.
#
# Таблица costs_short (информация о затратах на маркетинг):
#
# * Channel — идентификатор рекламного источника,
# * Dt — дата,
# * Costs — затраты на этот рекламный источник в этот день.

# %% [markdown]
# ## Библиотеки

# %%
# подгружаю библиотеки
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt

# %% [markdown]
# ## Предобработка данных

# %%
def first_view(df):  #функция для первого осмотра данных
    print(df.info())
    display (df.head())

# %% [markdown]
# ### Таблица visits

# %%
visits = pd.read_csv('visits_info_short.csv') # достаю таблицу с данными по посещениям приложения
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
# ...

# %%
# привожу названия столбцов к "змеиному стилю"
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel        session_start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
# ...

# %%
# преобразую данны о времени в тип datetime
visits['session_start'] = pd.to_datetime(visits['session_start'],  format = '%Y-%m-%d %H:%M:%S')
visits['session_end'] = pd.to_datetime(visits['session_end'], format = '%Y-%m-%d %H:%M:%S')
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# ...

# %% [markdown]
# ### Таблица orders

# %%
orders = pd.read_csv('orders_info_short.csv') # достаю таблицу с данными по покупкам
first_view(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %%
# привожу названия столбцов к "змеиному стилю"
orders.columns = ['user_id', 'event_dt', 'revenue']
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# ...

# %%
# преобразую данны о времени в тип datetime
orders['event_dt'] = pd.to_datetime(orders['event_dt'], format = '%Y-%m-%d %H:%M:%S')
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# ...

# %% [markdown]
# ### Таблица costs

# %%
costs = pd.read_csv('costs_info_short.csv') # достаю таблицу с данными о рекламных расходах
first_view(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
# привожу названия столбцов к "змеиному стилю"
costs = costs.rename(columns ={'Channel':'channel'})
first_view(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %%
# преобразую данны о времени в тип datetime
costs['dt'] = pd.to_datetime(costs['dt']).dt.date 
first_view(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB
# None
#         user_id         region   device  channel       session_start  \
# 0  981449118918  United States   iPhone  organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop 2019-05-01 00:29:59
# ...

# %% [markdown]
# В таблицах нет пропущенных значений. Проверяю на дубликаты.

# %%
def find_duplicates(df):
    s = df.duplicated().sum()
    print(f'В таблице найдено {s} полных дубликатов.')

# %%
find_duplicates(visits)
print(visits.duplicated(subset = ['user_id', 'session_start']).sum()) # проверяю дубликаты по двум полям в таблице visits

find_duplicates(orders)
print(orders.duplicated(subset = ['user_id', 'event_dt']).sum()) # проверяю дубликаты по двум полям в таблице orders

find_duplicates(costs)
# Out:
# В таблице найдено 0 полных дубликатов.
# 0
# В таблице найдено 0 полных дубликатов.
# 0
# В таблице найдено 0 полных дубликатов.

# %% [markdown]
# Дубликатов нет
#
# ### Вывод "Предобработка данных"
# В таблицах находятся данные по заходам в приложение, о покупках и о рекламных расходах.
# Эти данные позволят провести исследовательский анализ.
#
# Для всех таблиц названия столбцов были приведены к "змеиному стилю", данным о времени во всех таблицах был присвоен тип datetime.
# Дубликатов в таблицах не обнаружилось.

# %% [markdown]
# ## Функции для расчета и анализа LTV, ROI, удержания и конверсии

# %% [markdown]
# ### Функция для расчета ltv и roi

# %%
# функция для расчета ltv и roi
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # сохраняем в датафрейм данные пользователей и значения CAC, 
        # добавив параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функция для сглаживания фрейма

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# ### Функция для визуализации LTV и ROI

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=4):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(10, 30))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(5, 1, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(5, 1, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(5, 1, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(5, 1, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(5, 1, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для расчета удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для визуализации удержания

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Функция для расчета конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )   
    
    result_raw
    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для визуализации конверсии

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных
#
# Нужно узнать:
# * Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?
# * Какими устройствами они пользуются? С каких устройств чаще всего заходят платящие пользователи?
# * По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %% [markdown]
# ### Профили пользователей
#
# Создаю профили пользователей.

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = pd.to_datetime(profiles['first_ts']).dt.date
    profiles['month'] = pd.to_datetime(profiles['first_ts']).astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

   
    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']
    

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю (и некоторых неорганических тоже)
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)
   

    return profiles

# %%
profiles = get_profiles(visits, orders, costs) #вызываю функцию для построения таблицы профилей пользователей
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True          1.088172
# 1  2019-07-09 2019-07-01  False          1.107237
# 2  2019-10-01 2019-10-01  False          0.000000
# 3  2019-08-22 2019-08-01  False          0.988235
# 4  2019-10-02 2019-10-01  False          0.230769

# %% [markdown]
# ### Минимальная и максимальная даты привлечения пользователя.

# %% [markdown]
# Из условий задания получается, что минимальная дата привлечения пользователей - 1 мая 2009 года.
# Из условий задания можно вынести, что "в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через 2 недели после привлечения", а момент анализа - 1 ноября 2019 года.
# Максимальную дату привлечения можно рассчитать по формуле "момент анализа данных - горизонт анализа данных"

# %%
min_date = profiles['dt'].min() #минимальная дата привлечения пользователей
print(min_date ) # проверяю, что в таблице наименьшая дата действительно 1 мая 2019 года

max_date = profiles['dt'].max() #минимальная дата привлечения пользователей
print(max_date) # проверяю, что в таблице наибольшая дата действительно 27 октября 2019 года
# Out:
# 2019-05-01
# 2019-10-27

# %% [markdown]
# ### Из каких стран приходят посетители? Какие страны дают больше всего платящих пользователей?

# %%
def res_analisys(df, parameter = []):
    data = df.groupby(parameter).agg({'user_id': 'nunique'}) #всего уникальных пользователей по регионам
    
    pay_data = (
    df.query('payer == True')
    .groupby(parameter).agg({'user_id': 'nunique'})) # всего платящих уникальных пользователей по регионам
    
    data = data.merge(pay_data, on = parameter, how = 'left', suffixes = ('_total', '_payer'))
    
    data['payers, %'] = round((data['user_id_payer']/data['user_id_total'])*100,1) 
    
    display(data.sort_values(by='payers, %', ascending = False)) #сортирую данные по доле платящих пользователей

# %%
country = res_analisys(profiles, parameter = ['region'])
# Out:
#                user_id_total  user_id_payer  payers, %
# region
# United States         100002           6902        6.9
# Germany                14981            616        4.1
# UK                     17575            700        4.0
# France                 17450            663        3.8

# %% [markdown]
# #### Вывод
# Посетители приходят из 4 стран:
# * США,
# * Германия,
# * Великобритания,
# * Франция
#
# Самый большой трафик пользователей приходит из США, они же совершают больше всего покупок, но платящие пользователи не превышают 6% от общего количества пользователей.

# %% [markdown]
# ### Какими устройствами пользуются? С каких устройств чаще всего заходят платящие пользователи?

# %%
devices = res_analisys(profiles, parameter = ['device'])
# Out:
#          user_id_total  user_id_payer  payers, %
# device
# Mac              30042           1912        6.4
# iPhone           54479           3382        6.2
# Android          35032           2050        5.9
# PC               30455           1537        5.0

# %% [markdown]
# #### Вывод
# Больше всего трафик у пользователей iPhone и количество платящих самое большое, однако, пользователи Mac немного чаще совершают покупки, 6.4% пользователей из зашедших с Mac что-то покупают.

# %% [markdown]
# ### По каким рекламным каналам шло привлечение пользователей? Какие каналы приносят больше всего платящих пользователей?

# %%
channel = devices = res_analisys(profiles, parameter = ['channel'])
# Out:
#                     user_id_total  user_id_payer  payers, %
# channel
# FaceBoom                    29144           3557       12.2
# AdNonSense                   3880            440       11.3
# lambdaMediaAds               2149            225       10.5
# TipTop                      19561           1878        9.6
# RocketSuperAds               4448            352        7.9
# WahooNetBanner               8553            453        5.3
# YRabbit                      4312            165        3.8
# MediaTornado                 4364            156        3.6
# LeapBob                      8553            262        3.1
# OppleCreativeMedia           8605            233        2.7
# organic                     56439           1160        2.1

# %% [markdown]
# #### Вывод
# Привлечение пользователей шло по 11 каналам.
# Самые эффективные каналы:
# * FaceBoom
# * AdNonSense
# * lambdaMediaAds
# * TipTop
#
# Органический трафик самый большой, но он самый неэффективный, всего 2.1% пользователей совершаю покупки.
# Самый эффективный канал привлечения - FaceBoom, 12.2% пользователей, пришедших через него, совершают покупки.

# %% [markdown]
# ### Вывод "Исследовательский анализ данных"
#
# Я посмотрела на базовые значения конверсии пользователей в покупатели по регионам, устройствам и каналам привлечения.
#
# Выводы:
# * Самым крупным рынком является рынок США и у этого рынка самая высокая конверсия пользователей в покупатели.
# * Самое популярное устройство - iPhone, с него больше всего посещений и покупок, но конверсия выше на Mac-устройствах.
# * Пользователи предпочитают мобильные устройства стационарным.
# * Больше всего посетителей пришло с органического трафика, но у них самая низкая конверсия в покупателей.
# * Самая высокая конверсия в покупателей на канале FaceBoom и это второй по количеству переходов в приложение канал.

# %% [markdown]
# ## Расходы на маркетинг
#
# Необходимо выяснить:
# * Сколько денег потратили всего / на каждый источник / по времени ?
# * Сколько в среднем стоило привлечение одного покупателя из каждого источника?

# %% [markdown]
# Рассчитываю общую сумму расходов на маркетинг, выясняю, как траты распределены по источникам, строю график изменения метрик во времени.

# %%
print('Общая сумма расходов на маркетинг:', profiles['acquisition_cost'].sum().astype('int'))
# Out:
# Общая сумма расходов на маркетинг: 105497

# %%
marketing_cost = (profiles
 .pivot_table(index = 'channel', values ='acquisition_cost', aggfunc= 'sum')
 .sort_values(by='acquisition_cost', ascending=False))

marketing_cost['%'] = round(marketing_cost['acquisition_cost']/profiles['acquisition_cost'].sum()*100,1)

marketing_cost
# Out:
#                     acquisition_cost     %
# channel
# TipTop                      54751.30  51.9
# FaceBoom                    32445.60  30.8
# WahooNetBanner               5151.00   4.9
# AdNonSense                   3911.25   3.7
# OppleCreativeMedia           2151.25   2.0
# RocketSuperAds               1833.00   1.7
# LeapBob                      1797.60   1.7
# lambdaMediaAds               1557.60   1.5
# MediaTornado                  954.48   0.9
# YRabbit                       944.22   0.9
# organic                         0.00   0.0

# %% [markdown]
# 59% бюджета, потраченного на рекламу с 1 мая по 27 октября 2017 года ушло на канал TipTop, однако, доля покупателей в этом канале не является самой высокой, следовательно, канал не очень эффективен.
#
# Вторым по затратам бюджета является FaceBoom и он самый эффективный канал привлечения, 12.2 % пользователей пришедших через него сделали покупки.

# %%
#строю график трат на рекламу по каналам привлечения
profiles.pivot_table(
    index='dt',  # даты первых посещений
    columns='channel',  # источники переходов
    values='acquisition_cost',  # стоимость рекламы
    aggfunc='mean',  # подсчёт среднего
).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# На графике видно, что затраты на канал TipTop постоянно увеличиваются

# %%
#строю график трат на рекламу по TipTop
(profiles.query('channel in ["TipTop"]')
.pivot_table(
    index='dt',  # даты первых посещений
    columns='channel',  # источники переходов
    values='acquisition_cost',  # стоимость рекламы
    aggfunc='mean',  # подсчёт среднего
)).plot(figsize=(15, 5), grid=True)

plt.show()

# %% [markdown]
# ### Вывод "Расходы на маркетинг"
# Самый затратный канал привлечения пользователей - TipTop, а его эффективность 9.6% пользователей, совершивших покупки, на него уходит 52% рекламного бюджета.
# На FaceBoom	уходит 30% рекламного бюджета, а его эффективность - 12% пользователей, совершивших покупки.
#
#
# Стоимость привлечения органических пользователей равна нулю, так как они пришли сами. Стоимость всех остальных каналов не превышает 1 доллар за пользователя.
# Но расходы на канала TipTop постоянно увеличиваются начиная с июня и к ноябрю достигают 3.5 долларов.

# %% [markdown]
# ## Расчет среднего CAC
# Нужно узнать, сколько в среднем стоило привлечение одного пользователя из каждого источника.

# %%
# рассчитываю CAC по всему проекту
cac_one_user = (profiles.query('channel != "organic"') #убираю органический трафик, так как они пришли сами бесплатно
 .pivot_table(index =['dt'],
              values = ['user_id', 'acquisition_cost'],
              aggfunc = ({'user_id':'nunique', 'acquisition_cost':'sum'}))
)

cac_one_user['cac_one_user'] = round(cac_one_user['acquisition_cost']/cac_one_user['user_id'], 2)

cac_one_user.sort_values(by = 'cac_one_user', ascending = False)
# Out:
#             acquisition_cost  user_id  cac_one_user
# dt
# 2019-10-21           818.420      580          1.41
# 2019-09-15           767.285      548          1.40
# 2019-09-17           663.295      476          1.39
# 2019-10-10           711.200      511          1.39
# 2019-10-03           984.255      712          1.38
# ...                      ...      ...           ...
# 2019-05-16           271.480      376          0.72
# 2019-05-02           230.845      323          0.71
# 2019-05-11           334.900      472          0.71
# 2019-05-09           243.670      343          0.71
# 2019-05-12           279.360      393          0.71
#
# [180 rows x 3 columns]

# %%
cac_one_user['cac_one_user'].describe() # нахожу min, max и средннюю цену по дням
# Out:
# count    180.000000
# mean       1.104889
# std        0.188046
# min        0.710000
# 25%        0.970000
# 50%        1.135000
# 75%        1.252500
# max        1.410000
# Name: cac_one_user, dtype: float64

# %% [markdown]
# Самый дорогой пользователь по всем источникам привлечения, кроме органического трафика, был привлечен 21.10.2019 и стоил 1.41, самый дешевый – 12.05.2019 и стоил 0.71 . Средняя стоимость привлечения пользователя - 1.35.
# Если рассчитывать стоимость привлечения только по дням, без учета канала привлечения, то в целом все выглядит красиво, стандартное отклонение небольшое.

# %%
#рассчитываю стоимость привлечения пользователя по источникам
cac_one_user_channel = (profiles.query('channel != "organic"') #убираю органический трафик, так как они пришли сами бесплатно
 .pivot_table(index =['channel','dt'],
              values = ['user_id', 'acquisition_cost'],
              aggfunc = ({'user_id':'nunique', 'acquisition_cost':'sum'}))
)

cac_one_user_channel['cac_one_user'] = round(cac_one_user_channel['acquisition_cost']/cac_one_user_channel['user_id'], 2)

cac_one_user_channel.sort_values(by = 'cac_one_user', ascending = False)
# Out:
#                     acquisition_cost  user_id  cac_one_user
# channel dt
# TipTop  2019-10-11            483.00      130          3.72
#         2019-09-23            570.50      157          3.63
#         2019-09-26            542.50      150          3.62
#         2019-10-19            472.50      131          3.61
#         2019-10-20            472.50      131          3.61
# ...                              ...      ...           ...
# YRabbit 2019-07-09              2.16       15          0.14
#         2019-06-26              3.24       24          0.14
#         2019-06-10              2.34       18          0.13
#         2019-07-08              3.06       24          0.13
#         2019-07-25              1.62       13          0.12
#
# [1800 rows x 3 columns]

# %% [markdown]
# Стоимость привлечения самого дорогого пользователя по каналу TipTop в 3 раза выше самой дорогой стоимости привлечения пользователя, если ее "размазывать" по всем пользователям за день, а не по каналам.
# Самый дешевый пользователь приходил по каналу YRabbit и стоил 0.12 денежек.

# %%
cac_one_user_channel['cac_one_user'].describe()
# Out:
# count    1800.000000
# mean        0.739383
# std         0.760751
# min         0.120000
# 25%         0.230000
# 50%         0.560000
# 75%         0.992500
# max         3.720000
# Name: cac_one_user, dtype: float64

# %% [markdown]
# Самые дорогие пользователи пришли через канал TipTop, а самые дешевые через канал YRabbit.
# Средняя стоимость привлечения 0.56 по медиане.
# Стоимость привлечения пользователей через TipTop в 6,5 раз превышает среднюю стоимость привлечения пользователя.
#
# **Беру Топ-3 каналов по затратам на них и выясняю, где находятся значения относительно большей части данных по стоимости привлечения пользователей.**

# %%
#пишу функцию
def top_channel(df, channel):
    print('Стоимость привлечения по каналу', channel, 'выше медианной',
      df.query('channel == @channel and cac_one_user > 0.99')['cac_one_user']
      .count(),
      'дня из',
      df.query('channel == @channel')['cac_one_user'].count())

# %%
# проверяю, сколько раз стоимость привлечения пользователя TipTop превышает значение во 2 квартиле

top_channel(cac_one_user_channel, channel = "TipTop")
# Out:
# Стоимость привлечения по каналу TipTop выше медианной 169 дня из 180

# %% [markdown]
# Практически все пользователи, привлеченные по этому каналу, стоили больше, чем 75% остальных пользователей.

# %%
# проверяю, сколько раз стоимость привлечения пользователя FaceBoom превышает значение во 2 квартиле

top_channel(cac_one_user_channel, channel = "FaceBoom")
# Out:
# Стоимость привлечения по каналу FaceBoom выше медианной 180 дня из 180

# %%
# проверяю, сколько раз стоимость привлечения пользователя WahooNetBanner превышает значение во 2 квартиле

top_channel(cac_one_user_channel, channel = "WahooNetBanner")
# Out:
# Стоимость привлечения по каналу WahooNetBanner выше медианной 0 дня из 180

# %% [markdown]
# Хочу проверить, сколько платящих пользователей приходит по двум самым дорогим каналам.

# %%
print('Всего платящих пользователей:',profiles.query('payer == True')['payer'].count())


print('Платящие пользователи, пришедшие по каналу TipTop', 
      profiles.query('channel == "TipTop" and payer == True')['payer'].count())

print('Доля платящий пользователей, пришедших по каналу TipTop', 
      round(profiles.query('channel == "TipTop" and payer == True')['payer']
            .count()/profiles.query('payer == True')['payer'].count(),2))


print('Платящие пользователи, пришедшие по каналу FaceBoom', 
      profiles.query('channel == "FaceBoom" and payer == True')['payer'].count())

print('Доля платящий пользователей, пришедших по каналу FaceBoom', 
      round(profiles.query('channel == "FaceBoom" and payer == True')['payer']
            .count()/profiles.query('payer == True')['payer'].count(),2))
# Out:
# Всего платящих пользователей: 8881
# Платящие пользователи, пришедшие по каналу TipTop 1878
# Доля платящий пользователей, пришедших по каналу TipTop 0.21
# Платящие пользователи, пришедшие по каналу FaceBoom 3557
# Доля платящий пользователей, пришедших по каналу FaceBoom 0.4

# %% [markdown]
# #### Вывод "Расчеты на CAC"
# В ходе исследования выявлены очень высокие расходы на привлечение пользователей по каналу TipTop и FaceBoom, на привлечение по этим каналам уходит основная часть денег.
#
# При этом по каналу FaceBoom пришло до 40% пользователей, которые оплатили покупку, а по каналу FaceBoom только 21%.

# %% [markdown]
# ## Оценка окупаемости рекламы для привлечения пользователей

# %% [markdown]
# ### Горизонт и момент анализа

# %%
observation_date = datetime(2019, 11, 1).date() # задаю момент анализа
horizon_days = 14

# %% [markdown]
# Из дальнейшего анализа убираю органический трафик, так как он бесплатный, ROI всегда будет выше точки окупаемости, к тому же на него повлиять никак нельзя, или он перестанет быть органическим трафиком.

# %% [markdown]
# ### Общая окупаемость рекламы

# %%
# без органического трафика
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel !="organic"'), orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %%
# с органическим трафиком
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles, orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# #### Вывод "Общая окупаемость рекламы"
# * LTV плавно растет.
# * CAC тоже растет, скорее всего потому что стоимость привлечения по TipTop увеличивается.
# * ROI постепенно падает, это означает, что CAC растет быстрее LTV.
# * ROI не успевает достигнуть уровня окупаемости и в начиная с июня опускается ниже уровня окупаемости.
# * Органический трафик оказывает большое влияние на эффективность окупаемости рекламных кампаний.
#
# Реклама в целом не окупается, ищу причину, анализируя окупаемость рекламы по устойствам, странам и каналам.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по устройствам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel !="organic"'), orders, observation_date, horizon_days, dimensions=['device']
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# #### Вывод "Окупаемость рекламы с разбивкой по устройствам"
# * LTV растет.
# * CAC быстрее растет для iPhone и Mac, чем для Android и PC.
# * Только для PC ROI превышает уровень окупаемости на 12 день, скорее всего это связано с тем, что CAC для PC растет медленнее всего.
# * Динамика ROI показывает, для всех устройств показатель снижается и, начиная с сентября, уходит за уровень окупаемости.
#
# По устройствам наблюдается низкий ROI, ни одно устройство сильно не выделяется на графике, значит, дело не в устройстве, ищем дальше.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по странам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel !="organic"'), orders, observation_date, horizon_days, dimensions=['region']
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# #### Вывод "Окупаемость рекламы с разбивкой по странам"
# * LTV очень плавно растет.
# * CAC сильно растет для США, а для других регионов падает.
# * ROI для США не достигает точки окупаемости, для остальных регионов он переходит выше уровня окупаемости на 4-6 день.
# * Динамика ROI показывает, что для США ROI перестал переходить через уровень окупаемости в середине июня.
#
# Проблема наблюдается в США, стоимость привлечения очень большая и она увеличивается, но и рынок США и конверсия посетителей в пользователи выше, чем у остальных. Нужно исследовать дальше.

# %% [markdown]
# ### Окупаемость рекламы с разбивкой по рекламным каналам

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel !="organic"'), orders, observation_date, horizon_days, dimensions=['channel']
)
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# #### Вывод "Окупаемость рекламы с разбивкой по рекламным каналам"
# * LTV плавно растет, для TipTop и lambdaMediaAds этот показатель выше единицы.
# * CAC сильно растет TipTop, в то время как для других каналов этот показатель практически не меняется.
# * ROI для TipTop, FaceBoom и AdNonSense не достигают порога окупаемости.
# * Динамика ROI показывает, для lambdaMediaAds, Yrabbit и MediaTornado периодически появляются всплески повышенной окупаемости.
# * Так как для этих каналов CAC практически неизменен, то на ROI влияет увеличивающийся LTV.

# %% [markdown]
# ### Выводы "LTV, CAC, ROI"
# Самый большой показатель CAC в США и на канале привлечения TipTop и они растут.
# Окупаемость достигается только для PC, на остальных устройствах ROI не достигает порога окупаемости. Не смотря на то, что количество посещений с iPhone самое большое, CAC так же очень большой.
#
# Проверим гипотезу, что TipTop в основном вещает на США. Так же дополнительно проверю два других канала, по которым ROI не достигает окупаемости.

# %%
# сводная таблица по каналу TipTop с разбивкой на устройства
(profiles.query('channel == "TipTop"')
 .pivot_table(index = ['region', 'device'], values = ['user_id', 'payer'], aggfunc = {'user_id':'count','payer':'sum'})
)
# Out:
#                        payer  user_id
# region        device
# United States Android    409     3889
#               Mac        439     4820
#               PC         203     2012
#               iPhone     827     8840

# %%
# сводная таблица по каналу FaceBoom с разбивкой на устройства
(profiles.query('channel == "FaceBoom"')
 .pivot_table(index = ['region', 'device'], values = ['user_id', 'payer'], aggfunc = {'user_id':'count','payer':'sum'})
)
# Out:
#                        payer  user_id
# region        device
# United States Android    784     5875
#               Mac        886     7265
#               PC         357     3008
#               iPhone    1530    12996

# %%
# сводная таблица по каналу AdNonSense с разбивкой на устройства
(profiles.query('channel == "AdNonSense"')
 .pivot_table(index = ['region', 'device'], values = ['user_id', 'payer'], aggfunc = {'user_id':'count','payer':'sum'})
)
# Out:
#                  payer  user_id
# region  device
# France  Android     45      413
#         Mac         18      144
#         PC          53      524
#         iPhone      34      285
# Germany Android     37      329
#         Mac         10      148
#         PC          63      501
#         iPhone      32      241
# UK      Android     36      367
#         Mac         11      118
#         PC          76      538
#         iPhone      25      272

# %% [markdown]
# Гипотеза подтвердилась, все 100% трафика приходят из США.  Меньше всего устройств, с которых приходят пользователи по очень дорогой рекламе - PC, поэтому для PC ROI переходит через линию уровня окупаемости, а iPhone, с которого больше всего переходов - нет.
# Так же дела обстоят и с FaceBoom, там доля iPhone еще выше.
#
# AdNonSense ничем не выделяется, у него низкий LTV, то есть пользователи заходят, но ничего не покупают.
#
# Перехожу к расчету конверсии и удержания.

# %% [markdown]
# ### Конверсия

# %%
# конверсия с разбивкой по устройствам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = ['device']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая высокая конверсия у Mac и iPhone.
# Конверсия PC самая низкая и на графике динамики видно, что она снижается в июле и октябре.

# %%
#конверсия с разбивкой по странам
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = ['region']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая высокая конверсия в США, она сильно выше, чем в других странах.

# %%
#конверсия с разбивкой по каналам привлечения
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, horizon_days, dimensions = ['channel']
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Самая высокая конверсия у FaceBoom, который на все 100% обеспечивает трафик из США. Получается, что это наиболее эффективный канал для продвижения в США, к тому же, через этот канал идет больше всего пользователей iPhone.
#
# За Faceboom идет AdNonSense и lambdaMediaAds.
#
# Органическая конверсия самая низкая, но она и ничего не стоила.

# %% [markdown]
# ### Удержание

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions = ['device']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Самое высокое удержание у пользователей PC, но оно не значительно превышает удержание по другим устройствам.
# В начале исследуемого периода удержание на PC было выше, затем снизилось на 15%.
# Удержание неплатящих пользователей сильно ниже, уже на 10 день их почти не остается.
#
# Можно сказать, что удержание не очень чувствительно к устройству.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions = ['region']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Самое низкое удержание у США, остальные страны находятся примерно на одном уровне.
# Удержание неплатящих пользователей низкое, к 10 дню они перестают возвращаться.

# %%
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, horizon_days, dimensions = ['channel']
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Самое низкое удержание у органического трафика и с FaceBoom, пользователи, приходящие с TipTop удерживаются как и все.

# %% [markdown]
# #### Вывод "Конверсия и удержание"
# Самая высокая конверсия у Mac и iPhone, самая низкая у PC. Пользователи предпочитают совершать покупки в приложении с/для мобильных устройств. Удержание для всех устройств примерно однаковое. что означает, что оно не зависит от типа устройства.
#
# Страна с самой высокой конверсией - США, но удержание у нее самое низкое. Это значит, что пользователи из США быстро решаются на покупки и больше не возвращаются.
#
# Конверсия через FaceBoom самая высокая, а удержание самое низкое, но так как я уже выяснила, что все 100% пользователей, пришедших через FaceBoom - пришли из США, то показатели будут меняться для этого канала так же.

# %% [markdown]
# ### Вывод
# Реклама целом не окупается, потому что расходы на некоторые каналы привлечения очень большие.
# Сильно снижает окупаемость рекламы США, канал TipTop и все устройства, кроме PC.
#
# Проблемы окупаемости вызваны высокими затратами на канал TipTop, который, похоже, транслирует рекламу только на США.
# Пользователи из США обладают высокой конверсией и низким удержанием, что означает, что они быстро совершают покупку, сокрее всего одну, уходят и больше не возвращаются.

# %%
orders.groupby('user_id')['user_id'].count().median() #среднее количество покупок на пользователя.
# Out:
# 3.0

# %%
visits.groupby('user_id')['user_id'].count().median() #среднее количество посещений на пользователя.
# Out:
# 2.0

# %% [markdown]
# Проверяю, будет ли окупаться реклама в целом, если убрать каналы привлечения с самым высоким CAC - "TipTop", "FaceBoom"

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel not in ["organic", "TipTop"]'), orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Если перестать тратить деньги на канал TipTop, то пользователь начнет окупаться уже на 9 день, что соответствует пожеланиям заказчиков, чтобы пользователи окупались не позднее 2 недель.
#
# Проверяю, будут ли окупаться пользователи, если убрать канал FaceBoom.

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel not in ["organic", "FaceBoom"]'), orders, observation_date, horizon_days    
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Отказа только от FaceBoom будет недостаточно, чтобы реклама начала окупаться в целом. ROI не достигает порога окупаемости, а CAC продолжает расти.
#
# Смотрю, что будет, если отказаться и от TipTop, и от FaceBoom

# %%
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel not in ["organic", "TipTop", "FaceBoom"]'), orders, observation_date, horizon_days
)

plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Реклама начнет окупаться уже на 4 день.
#
# Смотрю, сколько покупок и на какую сумму пропадет, если отказаться от TipTop и FaceBoom.

# %%
(profiles
  .pivot_table(index = 'region', values = ['payer','acquisition_cost'], aggfunc = 'sum')).astype('int')
# Out:
#                acquisition_cost  payer
# region
# France                     5075    663
# Germany                    4424    616
# UK                         5068    700
# United States             90928   6902

# %%
(profiles
 .query('channel not in ["TipTop", "FaceBoom"]')
 .pivot_table(index = 'region', values = ['payer','acquisition_cost'], aggfunc = 'sum')).astype('int')
# Out:
#                acquisition_cost  payer
# region
# France                     5075    663
# Germany                    4424    616
# UK                         5068    700
# United States              3731   1467

# %%
(profiles
 .query('channel not in ["TipTop"]')
 .pivot_table(index = 'region', values = ['payer','acquisition_cost'], aggfunc = 'sum')).astype('int')
# Out:
#                acquisition_cost  payer
# region
# France                     5075    663
# Germany                    4424    616
# UK                         5068    700
# United States             36177   5024

# %%
(profiles
 .query('channel not in ["FaceBoom"]')
 .pivot_table(index = 'region', values = ['payer','acquisition_cost'], aggfunc = 'sum')).astype('int')
# Out:
#                acquisition_cost  payer
# region
# France                     5075    663
# Germany                    4424    616
# UK                         5068    700
# United States             58483   3345

# %% [markdown]
# Отказываться от FaceBoom неправильно, оттуда идет большой трафик покупателей, больше, чем из других стран вместе взятых. Проблема в высокой стоимости TipTop или непривлекательности приложения или того, что в нем продается для США, так как продаж тоже достаточно много, но их меньше, чем от FaceBoom.

# %% [markdown]
# ## Вывод по исследованию
#
# Причины неэффективности рекламных кампаний заключаются в высокой цене на канал продаж TipTop, стоимость рекламы выше, чем сумма покупок. На этот канал тратится до 52% рекламного бюджета.
# TipTop работает только на США, пользователи этой страны в течение 14 дней принимают решение о покупке на минимальную сумму и больше не возвращаются.
# Можно предположить, что товар или услуга, которые предлагает приложение - не интересны пользователям более 1 раза.
# Тем не менее, рынок США для данного приложения является самым крупным.

# %%
a = visits.merge(orders, on ='user_id', how = 'left')
a['revenue'] = a['revenue'].fillna(0)
a.pivot_table(index = ['region','revenue'], values = 'user_id', aggfunc = 'nunique')
# Out:
#                        user_id
# region        revenue
# France        0.00       16787
#               4.99         658
#               5.99          65
#               9.99          53
#               19.99         30
#               49.99         14
# Germany       0.00       14365
#               4.99         616
#               5.99          55
#               9.99          28
#               19.99         16
#               49.99         12
# UK            0.00       16875
#               4.99         693
#               5.99          75
#               9.99          36
#               19.99         33
#               49.99         36
# United States 0.00       93100
#               4.99        6781
#               5.99         514
#               9.99         248
#               19.99        123
#               49.99        146

# %%
#Количество покупок по TipTop
a.query('channel == "TipTop"').pivot_table(index = ['region','revenue'], values = 'user_id', aggfunc = 'nunique')
# Out:
#                        user_id
# region        revenue
# United States 0.00       18150
#               4.99        2051
#               5.99         265
#               9.99         117
#               19.99         55
#               49.99         70

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# Необходимо увеличить количество платящих пользователей из США, либо увеличить стоимость продукта/услуги, количество продаж или уменьшить расходы на рекламу.
#
#
# Так же нужно проверить, что у пользователей из США не возникает никаких технических проблем при оплате.
#
# Если технических проблем нет, то рекламный бюджет стоит перераспределить с TipTop на FaceBoom, так как количество платящих пользователей, приходящих через этот канал выше и оба канала работают только на США.
#
# Если от TipTop отказаться нельзя, то:
# * Для уменьшения расходов на рекламу предлагаю попробовать сменить форму оплаты для TipTop за рекламу, например на CPA за покупку.
# * Так же можно попробовать увеличить стоимость разовой минимальной покупки только для США.
# * Или провести анализ привлекательности продукта/услуги, продаваемых в приложении.
# * Провести UX-тестирование интерфейса, возможно, пользователь не может найти кнопку "Оплатить".
